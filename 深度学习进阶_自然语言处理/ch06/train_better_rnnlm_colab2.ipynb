# %%
# !pip install tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (4.64.1)

# %%
# coding: utf-8
import sys
sys.path.append('..')
import time
# import cupy
import matplotlib.pyplot as plt
# 在用GPU运行时，请打开下面的注释（需要cupy）
# ==============================================
GPU = True
# ==============================================
from tqdm.auto import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
if GPU:
    import cupy as np
    import cupyx
    np.cuda.set_allocator(np.cuda.MemoryPool().malloc)

    print('\033[92m' + '-' * 60 + '\033[0m')
    print(' ' * 23 + '\033[92mGPU Mode (cupy)\033[0m')
    print('\033[92m' + '-' * 60 + '\033[0m\n')
else:
    import numpy as np
    print('dasd')
# Out:
# ------------------------------------------------------------
#                        GPU Mode (cupy)
# ------------------------------------------------------------

# %%
# from common.optimizer import SGD
class SGD:
    '''
    随机梯度下降法（Stochastic Gradient Descent）
    '''
    def __init__(self, lr=0.01):
        self.lr = lr
        
    def update(self, params, grads):
        for i in range(len(params)):
            params[i] -= self.lr * grads[i]

# %%
# from common.trainer import RnnlmTrainer
class RnnlmTrainer:
    def __init__(self, model, optimizer):
        self.model = model
        self.optimizer = optimizer
        self.time_idx = None
        self.ppl_list = None
        self.eval_interval = None
        self.current_epoch = 0

    def get_batch(self, x, t, batch_size, time_size):
        batch_x = np.empty((batch_size, time_size), dtype='i')
        batch_t = np.empty((batch_size, time_size), dtype='i')

        data_size = len(x)
        jump = data_size // batch_size
        offsets = [i * jump for i in range(batch_size)]  # mini-batch的各笔样本数据的开始位置

        for time in range(time_size):
            for i, offset in enumerate(offsets):
                batch_x[i, time] = x[(offset + self.time_idx) % data_size]
                batch_t[i, time] = t[(offset + self.time_idx) % data_size]
            self.time_idx += 1
        return batch_x, batch_t

    def fit(self, xs, ts, max_epoch=10, batch_size=20, time_size=35,
            max_grad=None, eval_interval=20):
        data_size = len(xs)
        max_iters = data_size // (batch_size * time_size)
        self.time_idx = 0
        self.ppl_list = []
        self.eval_interval = eval_interval
        model, optimizer = self.model, self.optimizer
        total_loss = 0
        loss_count = 0

        start_time = time.time()
        for epoch in range(max_epoch):
            for iters in tqdm(range(max_iters)):
                batch_x, batch_t = self.get_batch(xs, ts, batch_size, time_size)

                # 计算梯度，更新参数
                loss = model.forward(batch_x, batch_t)
                model.backward()
                params, grads = remove_duplicate(model.params, model.grads)  # 将共享的权重整合为1个
                if max_grad is not None:
                    clip_grads(grads, max_grad)
                optimizer.update(params, grads)
                total_loss += loss
                loss_count += 1

                # 评价困惑度
                if (eval_interval is not None) and (iters % eval_interval) == 0:
                    ppl = np.exp(total_loss / loss_count)
                    elapsed_time = time.time() - start_time
                    print('| epoch %d |  iter %d / %d | time %d[s] | perplexity %.2f'
                          % (self.current_epoch + 1, iters + 1, max_iters, elapsed_time, ppl))
                    self.ppl_list.append(float(ppl))
                    total_loss, loss_count = 0, 0

            self.current_epoch += 1

    def plot(self, ylim=None):
        x = numpy.arange(len(self.ppl_list))
        if ylim is not None:
            plt.ylim(*ylim)
        plt.plot(x, self.ppl_list, label='train')
        plt.xlabel('iterations (x' + str(self.eval_interval) + ')')
        plt.ylabel('perplexity')
        plt.show()

# %%
# from common.util import eval_perplexity, to_gpu
def eval_perplexity(model, corpus, batch_size=10, time_size=35):
    print('evaluating perplexity ...')
    corpus_size = len(corpus)
    total_loss, loss_cnt = 0, 0
    max_iters = (corpus_size - 1) // (batch_size * time_size)
    jump = (corpus_size - 1) // batch_size

    for iters in range(max_iters):
        xs = np.zeros((batch_size, time_size), dtype=np.int32)
        ts = np.zeros((batch_size, time_size), dtype=np.int32)
        time_offset = iters * time_size
        offsets = [time_offset + (i * jump) for i in range(batch_size)]
        for t in range(time_size):
            for i, offset in enumerate(offsets):
                xs[i, t] = corpus[(offset + t) % corpus_size]
                ts[i, t] = corpus[(offset + t + 1) % corpus_size]

        try:
            loss = model.forward(xs, ts, train_flg=False)
        except TypeError:
            loss = model.forward(xs, ts)
        total_loss += loss

        sys.stdout.write('\r%d / %d' % (iters, max_iters))
        sys.stdout.flush()

    print('')
    ppl = np.exp(total_loss / max_iters)
    return ppl


def to_cpu(x):
    import numpy
    if type(x) == numpy.ndarray:
        return x
    return np.asnumpy(x)

def to_gpu(x):
    import cupy
    if type(x) == cupy.ndarray:
        return x
    return cupy.asarray(x)

# %%
import os
import pickle
class BaseModel:
    def __init__(self):
        self.params, self.grads = None, None

    def forward(self, *args):
        raise NotImplementedError

    def backward(self, *args):
        raise NotImplementedError

    def save_params(self, file_name=None):
        if file_name is None:
            file_name = self.__class__.__name__ + '.pkl'

        params = [p.astype(np.float16) for p in self.params]
        if GPU:
            params = [to_cpu(p) for p in params]

        with open(file_name, 'wb') as f:
            pickle.dump(params, f)

    def load_params(self, file_name=None):
        if file_name is None:
            file_name = self.__class__.__name__ + '.pkl'

        if '/' in file_name:
            file_name = file_name.replace('/', os.sep)

        if not os.path.exists(file_name):
            raise IOError('No file: ' + file_name)

        with open(file_name, 'rb') as f:
            params = pickle.load(f)

        params = [p.astype('f') for p in params]
        if GPU:
            params = [to_gpu(p) for p in params]

        for i, param in enumerate(self.params):
            param[...] = params[i]

# %%
def softmax(x):
    if x.ndim == 2:
        x = x - x.max(axis=1, keepdims=True)
        x = np.exp(x)
        x /= x.sum(axis=1, keepdims=True)
    elif x.ndim == 1:
        x = x - np.max(x)
        x = np.exp(x) / np.sum(np.exp(x))

    return x

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
class Dropout:
    '''
    http://arxiv.org/abs/1207.0580
    '''
    def __init__(self, dropout_ratio=0.5):
        self.params, self.grads = [], []
        self.dropout_ratio = dropout_ratio
        self.mask = None

    def forward(self, x, train_flg=True):
        if train_flg:
            self.mask = np.random.rand(*x.shape) > self.dropout_ratio
            return x * self.mask
        else:
            return x * (1.0 - self.dropout_ratio)

    def backward(self, dout):
        return dout * self.mask
    
class Embedding:
    def __init__(self, W):
        self.params = [W]
        self.grads = [np.zeros_like(W)]
        self.idx = None

    def forward(self, idx):
        W, = self.params
        self.idx = idx
        out = W[idx]
        return out

    def backward(self, dout):
        dW, = self.grads
        dW[...] = 0
        if GPU:
            cupyx.scatter_add(dW, self.idx, dout)
        else:
            np.add.at(dW, self.idx, dout)
        return None
    
class LSTM:
    def __init__(self, Wx, Wh, b):
        '''

        Parameters
        ----------
        Wx: 输入`x`用的权重参数（整合了4个权重）
        Wh: 隐藏状态`h`用的权重参数（整合了4个权重）
        b: 偏置（整合了4个偏置）
        '''
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.cache = None

    def forward(self, x, h_prev, c_prev):
        Wx, Wh, b = self.params
        N, H = h_prev.shape

        A = np.dot(x, Wx) + np.dot(h_prev, Wh) + b

        f = A[:, :H]
        g = A[:, H:2*H]
        i = A[:, 2*H:3*H]
        o = A[:, 3*H:]

        f = sigmoid(f)
        g = np.tanh(g)
        i = sigmoid(i)
        o = sigmoid(o)

        c_next = f * c_prev + g * i
        h_next = o * np.tanh(c_next)

        self.cache = (x, h_prev, c_prev, i, f, g, o, c_next)
        return h_next, c_next

    def backward(self, dh_next, dc_next):
        Wx, Wh, b = self.params
        x, h_prev, c_prev, i, f, g, o, c_next = self.cache

        tanh_c_next = np.tanh(c_next)

        ds = dc_next + (dh_next * o) * (1 - tanh_c_next ** 2)

        dc_prev = ds * f

        di = ds * g
        df = ds * c_prev
        do = dh_next * tanh_c_next
        dg = ds * i

        di *= i * (1 - i)
        df *= f * (1 - f)
        do *= o * (1 - o)
        dg *= (1 - g ** 2)

        dA = np.hstack((df, dg, di, do))

        dWh = np.dot(h_prev.T, dA)
        dWx = np.dot(x.T, dA)
        db = dA.sum(axis=0)

        self.grads[0][...] = dWx
        self.grads[1][...] = dWh
        self.grads[2][...] = db

        dx = np.dot(dA, Wx.T)
        dh_prev = np.dot(dA, Wh.T)

        return dx, dh_prev, dc_prev

# %%
class TimeEmbedding:
    def __init__(self, W):
        self.params = [W]
        self.grads = [np.zeros_like(W)]
        self.layers = None
        self.W = W

    def forward(self, xs):
        N, T = xs.shape
        V, D = self.W.shape

        out = np.empty((N, T, D), dtype='f')
        self.layers = []

        for t in range(T):
            layer = Embedding(self.W)
            out[:, t, :] = layer.forward(xs[:, t])
            self.layers.append(layer)

        return out

    def backward(self, dout):
        N, T, D = dout.shape

        grad = 0
        for t in range(T):
            layer = self.layers[t]
            layer.backward(dout[:, t, :])
            grad += layer.grads[0]

        self.grads[0][...] = grad
        return None
    
class TimeDropout:
    def __init__(self, dropout_ratio=0.5):
        self.params, self.grads = [], []
        self.dropout_ratio = dropout_ratio
        self.mask = None
        self.train_flg = True

    def forward(self, xs):
        if self.train_flg:
            flg = np.random.rand(*xs.shape) > self.dropout_ratio
            scale = 1 / (1.0 - self.dropout_ratio)
            self.mask = flg.astype(np.float32) * scale

            return xs * self.mask
        else:
            return xs

    def backward(self, dout):
        return dout * self.mask
    
class TimeLSTM:
    def __init__(self, Wx, Wh, b, stateful=False):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.layers = None

        self.h, self.c = None, None
        self.dh = None
        self.stateful = stateful

    def forward(self, xs):
        Wx, Wh, b = self.params
        N, T, D = xs.shape
        H = Wh.shape[0]

        self.layers = []
        hs = np.empty((N, T, H), dtype='f')

        if not self.stateful or self.h is None:
            self.h = np.zeros((N, H), dtype='f')
        if not self.stateful or self.c is None:
            self.c = np.zeros((N, H), dtype='f')

        for t in range(T):
            layer = LSTM(*self.params)
            self.h, self.c = layer.forward(xs[:, t, :], self.h, self.c)
            hs[:, t, :] = self.h

            self.layers.append(layer)

        return hs

    def backward(self, dhs):
        Wx, Wh, b = self.params
        N, T, H = dhs.shape
        D = Wx.shape[0]

        dxs = np.empty((N, T, D), dtype='f')
        dh, dc = 0, 0

        grads = [0, 0, 0]
        for t in reversed(range(T)):
            layer = self.layers[t]
            dx, dh, dc = layer.backward(dhs[:, t, :] + dh, dc)
            dxs[:, t, :] = dx
            for i, grad in enumerate(layer.grads):
                grads[i] += grad

        for i, grad in enumerate(grads):
            self.grads[i][...] = grad
        self.dh = dh
        return dxs

    def set_state(self, h, c=None):
        self.h, self.c = h, c

    def reset_state(self):
        self.h, self.c = None, None

class TimeAffine:
    def __init__(self, W, b):
        self.params = [W, b]
        self.grads = [np.zeros_like(W), np.zeros_like(b)]
        self.x = None

    def forward(self, x):
        N, T, D = x.shape
        W, b = self.params

        rx = x.reshape(N*T, -1)
        out = np.dot(rx, W) + b
        self.x = x
        return out.reshape(N, T, -1)

    def backward(self, dout):
        x = self.x
        N, T, D = x.shape
        W, b = self.params

        dout = dout.reshape(N*T, -1)
        rx = x.reshape(N*T, -1)

        db = np.sum(dout, axis=0)
        dW = np.dot(rx.T, dout)
        dx = np.dot(dout, W.T)
        dx = dx.reshape(*x.shape)

        self.grads[0][...] = dW
        self.grads[1][...] = db

        return dx
class TimeSoftmaxWithLoss:
    def __init__(self):
        self.params, self.grads = [], []
        self.cache = None
        self.ignore_label = -1

    def forward(self, xs, ts):
        N, T, V = xs.shape

        if ts.ndim == 3:  # 在监督标签为one-hot向量的情况下
            ts = ts.argmax(axis=2)

        mask = (ts != self.ignore_label)

        # 按批次大小和时序大小进行整理（reshape）
        xs = xs.reshape(N * T, V)
        ts = ts.reshape(N * T)
        mask = mask.reshape(N * T)

        ys = softmax(xs)
        ls = np.log(ys[np.arange(N * T), ts])
        ls *= mask  # 与ignore_label相应的数据将损失设为0
        loss = -np.sum(ls)
        loss /= mask.sum()

        self.cache = (ts, ys, mask, (N, T, V))
        return loss

    def backward(self, dout=1):
        ts, ys, mask, (N, T, V) = self.cache

        dx = ys
        dx[np.arange(N * T), ts] -= 1
        dx *= dout
        dx /= mask.sum()
        dx *= mask[:, np.newaxis]  # 与ignore_label相应的数据将梯度设为0

        dx = dx.reshape((N, T, V))

        return dx

# %%
# from better_rnnlm import BetterRnnlm
class BetterRnnlm(BaseModel):
    '''
     利用2个LSTM层并在各层使用Dropout的模型
     基于[1]提出的模型，利用weight tying[2][3]

     [1] Recurrent Neural Network Regularization (https://arxiv.org/abs/1409.2329)
     [2] Using the Output Embedding to Improve Language Models (https://arxiv.org/abs/1608.05859)
     [3] Tying Word Vectors and Word Classifiers (https://arxiv.org/pdf/1611.01462.pdf)
    '''
    def __init__(self, vocab_size=10000, wordvec_size=650,
                 hidden_size=650, dropout_ratio=0.5):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx1 = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh1 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b1 = np.zeros(4 * H).astype('f')
        lstm_Wx2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_Wh2 = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b2 = np.zeros(4 * H).astype('f')
        affine_b = np.zeros(V).astype('f')

        self.layers = [
            TimeEmbedding(embed_W),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx1, lstm_Wh1, lstm_b1, stateful=True),
            TimeDropout(dropout_ratio),
            TimeLSTM(lstm_Wx2, lstm_Wh2, lstm_b2, stateful=True),
            TimeDropout(dropout_ratio),
            TimeAffine(embed_W.T, affine_b)  # weight tying!!
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.lstm_layers = [self.layers[2], self.layers[4]]
        self.drop_layers = [self.layers[1], self.layers[3], self.layers[5]]

        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads

    def predict(self, xs, train_flg=False):
        for layer in self.drop_layers:
            layer.train_flg = train_flg

        for layer in self.layers:
            xs = layer.forward(xs)
        return xs

    def forward(self, xs, ts, train_flg=True):
        score = self.predict(xs, train_flg)
        loss = self.loss_layer.forward(score, ts)
        return loss

    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout

    def reset_state(self):
        for layer in self.lstm_layers:
            layer.reset_state()

# %%
# from dataset import ptb
# import sys 
# sys.path.append('..')
import os
try:
    import urllib.request
except ImportError:
    raise ImportError('Use Python3!')
import pickle


url_base = 'https://raw.githubusercontent.com/tomsercu/lstm/master/data/'
key_file = {
    'train':'ptb.train.txt',
    'test':'ptb.test.txt',
    'valid':'ptb.valid.txt'
}
save_file = {
    'train':'ptb.train.npy',
    'test':'ptb.test.npy',
    'valid':'ptb.valid.npy'
}
vocab_file = 'ptb.vocab.pkl'

dataset_dir = os.getcwd()


def _download(file_name):
    file_path = dataset_dir + '/' + file_name
    if os.path.exists(file_path):
        return

    print('Downloading ' + file_name + ' ... ')

    try:
        urllib.request.urlretrieve(url_base + file_name, file_path)
    except urllib.error.URLError:
        import ssl
        ssl._create_default_https_context = ssl._create_unverified_context
        urllib.request.urlretrieve(url_base + file_name, file_path)

    print('Done')


def load_vocab():
    vocab_path = dataset_dir + '/' + vocab_file

    if os.path.exists(vocab_path):
        with open(vocab_path, 'rb') as f:
            word_to_id, id_to_word = pickle.load(f)
        return word_to_id, id_to_word

    word_to_id = {}
    id_to_word = {}
    data_type = 'train'
    file_name = key_file[data_type]
    file_path = dataset_dir + '/' + file_name

    _download(file_name)

    words = open(file_path).read().replace('\n', '<eos>').strip().split()

    for i, word in enumerate(words):
        if word not in word_to_id:
            tmp_id = len(word_to_id)
            word_to_id[word] = tmp_id
            id_to_word[tmp_id] = word

    with open(vocab_path, 'wb') as f:
        pickle.dump((word_to_id, id_to_word), f)

    return word_to_id, id_to_word


def load_data(data_type='train'):
    '''
        :param data_type: 数据的种类：'train' or 'test' or 'valid (val)'
        :return:
    '''
    if data_type == 'val': data_type = 'valid'
    save_path = dataset_dir + '/' + save_file[data_type]

    word_to_id, id_to_word = load_vocab()

    if os.path.exists(save_path):
        corpus = np.load(save_path)
        return corpus, word_to_id, id_to_word

    file_name = key_file[data_type]
    file_path = dataset_dir + '/' + file_name
    _download(file_name)

    words = open(file_path).read().replace('\n', '<eos>').strip().split()
    corpus = np.array([word_to_id[w] for w in words])

    np.save(save_path, corpus)
    return corpus, word_to_id, id_to_word

# %%
# for data_type in ('train', 'val', 'test'):
#         load_data(data_type)

# %%
# 设定超参数
batch_size = 20
wordvec_size = 650
hidden_size = 650
time_size = 35
lr = 20.0
max_epoch = 40
max_grad = 0.25
dropout = 0.5

# %%
# 读入训练数据
corpus, word_to_id, id_to_word = load_data('train')
corpus_val, _, _ = load_data('val')
corpus_test, _, _ = load_data('test')

# %%
if GPU:
    corpus = to_gpu(corpus)
    corpus_val = to_gpu(corpus_val)
    corpus_test = to_gpu(corpus_test)

# %%
vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]

# %%
model = BetterRnnlm(vocab_size, wordvec_size, hidden_size, dropout)
optimizer = SGD(lr)
trainer = RnnlmTrainer(model, optimizer)

# %% [markdown]
# 这个改动是，针对每个 epoch 使用验证数据评价困惑度，在值变差时，降低学习率。

# %%
def remove_duplicate(params, grads):
    '''
    将参数列表中重复的权重整合为1个，
    加上与该权重对应的梯度
    '''
    params, grads = params[:], grads[:]  # copy list

    while True:
        find_flg = False
        L = len(params)

        for i in range(0, L - 1):
            for j in range(i + 1, L):
                # 在共享权重的情况下
                if params[i] is params[j]:
                    grads[i] += grads[j]  # 加上梯度
                    find_flg = True
                    params.pop(j)
                    grads.pop(j)
                # 在作为转置矩阵共享权重的情况下（weight tying）
                elif params[i].ndim == 2 and params[j].ndim == 2 and \
                     params[i].T.shape == params[j].shape and np.all(params[i].T == params[j]):
                    grads[i] += grads[j].T
                    find_flg = True
                    params.pop(j)
                    grads.pop(j)

                if find_flg: break
            if find_flg: break

        if not find_flg: break

    return params, grads

def clip_grads(grads, max_norm):
    total_norm = 0
    for grad in grads:
        total_norm += np.sum(grad ** 2)
    total_norm = np.sqrt(total_norm)

    rate = max_norm / (total_norm + 1e-6)
    if rate < 1:
        for grad in grads:
            grad *= rate

# %%
best_ppl = float('inf')
for epoch in range(max_epoch):
    trainer.fit(xs, ts, max_epoch=1, batch_size=batch_size,
                time_size=time_size, max_grad=max_grad)

    model.reset_state()
    ppl = eval_perplexity(model, corpus_val)
    print('valid perplexity: ', ppl)

    if best_ppl > ppl:
        best_ppl = ppl
        model.save_params()
    else:
        lr /= 4.0
        optimizer.lr = lr

    model.reset_state()
    print('-' * 50)
# Out:
#   0%|          | 0/1327 [00:00<?, ?it/s]
# | epoch 1 |  iter 1 / 1327 | time 7[s] | perplexity 10000.01
# | epoch 1 |  iter 21 / 1327 | time 12[s] | perplexity 3720.74
# | epoch 1 |  iter 41 / 1327 | time 16[s] | perplexity 1913.80
# | epoch 1 |  iter 61 / 1327 | time 20[s] | perplexity 1346.81
# | epoch 1 |  iter 81 / 1327 | time 24[s] | perplexity 1045.03
# | epoch 1 |  iter 101 / 1327 | time 28[s] | perplexity 830.97
# | epoch 1 |  iter 121 / 1327 | time 32[s] | perplexity 785.13
# | epoch 1 |  iter 141 / 1327 | time 35[s] | perplexity 729.70
# | epoch 1 |  iter 161 / 1327 | time 39[s] | perplexity 679.97
# | epoch 1 |  iter 181 / 1327 | time 43[s] | perplexity 687.21
# | epoch 1 |  iter 201 / 1327 | time 47[s] | perplexity 597.58
# | epoch 1 |  iter 221 / 1327 | time 51[s] | perplexity 586.93
# | epoch 1 |  iter 241 / 1327 | time 55[s] | perplexity 526.03
# | epoch 1 |  iter 261 / 1327 | time 59[s] | perplexity 542.85
# | epoch 1 |  iter 281 / 1327 | time 63[s] | perplexity 523.71
# | epoch 1 |  iter 301 / 1327 | time 67[s] | perplexity 454.92
# | epoch 1 |  iter 321 / 1327 | time 71[s] | perplexity 386.06
# | epoch 1 |  iter 341 / 1327 | time 75[s] | perplexity 454.69
# | epoch 1 |  iter 361 / 1327 | time 79[s] | perplexity 471.32
# | epoch 1 |  iter 381 / 1327 | time 83[s] | perplexity 385.19
# | epoch 1 |  iter 401 / 1327 | time 87[s] | perplexity 402.37
# | epoch 1 |  iter 421 / 1327 | time 91[s] | perplexity 394.65
# | epoch 1 |  iter 441 / 1327 | time 95[s] | perplexity 380.95
# | epoch 1 |  iter 461 / 1327 | time 99[s] | perplexity 372.72
# | epoch 1 |  iter 481 / 1327 | time 103[s] | perplexity 350.75
# | epoch 1 |  iter 501 / 1327 | time 107[s] | perplexity 352.36
# | epoch 1 |  iter 521 / 1327 | time 111[s] | perplexity 346.04
# | epoch 1 |  iter 541 / 1327 | time 115[s] | perplexity 363.98
# | epoch 1 |  iter 561 / 1327 | time 119[s] | perplexity 323.90
# | epoch 1 |  iter 581 / 1327 | time 123[s] | perplexity 289.72
# | epoch 1 |  iter 601 / 1327 | time 127[s] | perplexity 374.00
# | epoch 1 |  iter 621 / 1327 | time 131[s] | perplexity 345.25
# | epoch 1 |  iter 641 / 1327 | time 135[s] | perplexity 315.76
# | epoch 1 |  iter 661 / 1327 | time 139[s] | perplexity 304.94
# | epoch 1 |  iter 681 / 1327 | time 143[s] | perplexity 257.14
# | epoch 1 |  iter 701 / 1327 | time 147[s] | perplexity 279.86
# | epoch 1 |  iter 721 / 1327 | time 151[s] | perplexity 286.42
# | epoch 1 |  iter 741 / 1327 | time 155[s] | perplexity 249.80
# | epoch 1 |  iter 761 / 1327 | time 159[s] | perplexity 258.98
# | epoch 1 |  iter 781 / 1327 | time 163[s] | perplexity 244.44
# | epoch 1 |  iter 801 / 1327 | time 167[s] | perplexity 271.48
# | epoch 1 |  iter 821 / 1327 | time 171[s] | perplexity 253.01
# | epoch 1 |  iter 841 / 1327 | time 175[s] | perplexity 256.74
# | epoch 1 |  iter 861 / 1327 | time 179[s] | perplexity 249.53
# | epoch 1 |  iter 881 / 1327 | time 183[s] | perplexity 228.87
# | epoch 1 |  iter 901 / 1327 | time 186[s] | perplexity 283.97
# | epoch 1 |  iter 921 / 1327 | time 191[s] | perplexity 252.12
# | epoch 1 |  iter 941 / 1327 | time 195[s] | perplexity 256.61
# | epoch 1 |  iter 961 / 1327 | time 198[s] | perplexity 275.16
# | epoch 1 |  iter 981 / 1327 | time 203[s] | perplexity 255.77
# | epoch 1 |  iter 1001 / 1327 | time 207[s] | perplexity 215.70
# | epoch 1 |  iter 1021 / 1327 | time 210[s] | perplexity 252.66
# | epoch 1 |  iter 1041 / 1327 | time 214[s] | perplexity 230.90
# | epoch 1 |  iter 1061 / 1327 | time 219[s] | perplexity 221.00
# | epoch 1 |  iter 1081 / 1327 | time 222[s] | perplexity 188.80
# | epoch 1 |  iter 1101 / 1327 | time 226[s] | perplexity 210.94
# | epoch 1 |  iter 1121 / 1327 | time 230[s] | perplexity 256.36
# | epoch 1 |  iter 1141 / 1327 | time 234[s] | perplexity 231.46
# | epoch 1 |  iter 1161 / 1327 | time 238[s] | perplexity 221.03
# | epoch 1 |  iter 1181 / 1327 | time 243[s] | perplexity 211.27
# | epoch 1 |  iter 1201 / 1327 | time 246[s] | perplexity 180.54
# | epoch 1 |  iter 1221 / 1327 | time 250[s] | perplexity 177.42
# | epoch 1 |  iter 1241 / 1327 | time 255[s] | perplexity 206.21
# | epoch 1 |  iter 1261 / 1327 | time 258[s] | perplexity 191.47
# | epoch 1 |  iter 1281 / 1327 | time 262[s] | perplexity 197.20
# | epoch 1 |  iter 1301 / 1327 | time 266[s] | perplexity 246.29
# | epoch 1 |  iter 1321 / 1327 | time 270[s] | perplexity 233.06
# evaluating perplexity ...
# 209 / 210
# valid perplexity:  199.15572
# --------------------------------------------------
#   0%|          | 0/1327 [00:00<?, ?it/s]
# | epoch 2 |  iter 1 / 1327 | time 0[s] | perplexity 287.56
# | epoch 2 |  iter 21 / 1327 | time 4[s] | perplexity 228.99
# | epoch 2 |  iter 41 / 1327 | time 8[s] | perplexity 213.35
# | epoch 2 |  iter 61 / 1327 | time 12[s] | perplexity 197.24
# | epoch 2 |  iter 81 / 1327 | time 16[s] | perplexity 179.84
# | epoch 2 |  iter 101 / 1327 | time 20[s] | perplexity 168.04
# | epoch 2 |  iter 121 / 1327 | time 23[s] | perplexity 181.95
# | epoch 2 |  iter 141 / 1327 | time 28[s] | perplexity 200.68
# | epoch 2 |  iter 161 / 1327 | time 32[s] | perplexity 215.93
# | epoch 2 |  iter 181 / 1327 | time 35[s] | perplexity 223.75
# | epoch 2 |  iter 201 / 1327 | time 40[s] | perplexity 206.12
# | epoch 2 |  iter 221 / 1327 | time 43[s] | perplexity 205.44
# | epoch 2 |  iter 241 / 1327 | time 47[s] | perplexity 197.61
# | epoch 2 |  iter 261 / 1327 | time 51[s] | perplexity 211.89
# | epoch 2 |  iter 281 / 1327 | time 55[s] | perplexity 206.06
# | epoch 2 |  iter 301 / 1327 | time 59[s] | perplexity 188.52
# | epoch 2 |  iter 321 / 1327 | time 63[s] | perplexity 153.60
# | epoch 2 |  iter 341 / 1327 | time 67[s] | perplexity 199.85
# | epoch 2 |  iter 361 / 1327 | time 71[s] | perplexity 216.52
# | epoch 2 |  iter 381 / 1327 | time 75[s] | perplexity 172.49
# | epoch 2 |  iter 401 / 1327 | time 79[s] | perplexity 195.25
# | epoch 2 |  iter 421 / 1327 | time 83[s] | perplexity 178.15
# | epoch 2 |  iter 441 / 1327 | time 87[s] | perplexity 181.15
# | epoch 2 |  iter 461 / 1327 | time 91[s] | perplexity 181.33
# | epoch 2 |  iter 481 / 1327 | time 94[s] | perplexity 174.11
# | epoch 2 |  iter 501 / 1327 | time 98[s] | perplexity 190.95
# | epoch 2 |  iter 521 / 1327 | time 103[s] | perplexity 189.93
# | epoch 2 |  iter 541 / 1327 | time 106[s] | perplexity 202.88
# | epoch 2 |  iter 561 / 1327 | time 110[s] | perplexity 172.45
# | epoch 2 |  iter 581 / 1327 | time 114[s] | perplexity 159.64
# | epoch 2 |  iter 601 / 1327 | time 118[s] | perplexity 218.08
# | epoch 2 |  iter 621 / 1327 | time 122[s] | perplexity 203.16
# | epoch 2 |  iter 641 / 1327 | time 126[s] | perplexity 185.51
# | epoch 2 |  iter 661 / 1327 | time 130[s] | perplexity 175.24
# | epoch 2 |  iter 681 / 1327 | time 134[s] | perplexity 148.15
# | epoch 2 |  iter 701 / 1327 | time 138[s] | perplexity 170.20
# | epoch 2 |  iter 721 / 1327 | time 142[s] | perplexity 175.76
# | epoch 2 |  iter 741 / 1327 | time 146[s] | perplexity 151.05
# | epoch 2 |  iter 761 / 1327 | time 150[s] | perplexity 151.15
# | epoch 2 |  iter 781 / 1327 | time 154[s] | perplexity 148.88
# | epoch 2 |  iter 801 / 1327 | time 157[s] | perplexity 169.08
# | epoch 2 |  iter 821 / 1327 | time 161[s] | perplexity 161.19
# | epoch 2 |  iter 841 / 1327 | time 166[s] | perplexity 165.30
# | epoch 2 |  iter 861 / 1327 | time 169[s] | perplexity 160.30
# | epoch 2 |  iter 881 / 1327 | time 173[s] | perplexity 147.86
# | epoch 2 |  iter 901 / 1327 | time 177[s] | perplexity 188.92
# | epoch 2 |  iter 921 / 1327 | time 181[s] | perplexity 166.60
# | epoch 2 |  iter 941 / 1327 | time 185[s] | perplexity 169.16
# | epoch 2 |  iter 961 / 1327 | time 189[s] | perplexity 183.83
# | epoch 2 |  iter 981 / 1327 | time 193[s] | perplexity 173.90
# | epoch 2 |  iter 1001 / 1327 | time 197[s] | perplexity 147.45
# | epoch 2 |  iter 1021 / 1327 | time 201[s] | perplexity 177.73
# | epoch 2 |  iter 1041 / 1327 | time 205[s] | perplexity 157.66
# | epoch 2 |  iter 1061 / 1327 | time 208[s] | perplexity 147.17
# | epoch 2 |  iter 1081 / 1327 | time 213[s] | perplexity 123.70
# | epoch 2 |  iter 1101 / 1327 | time 216[s] | perplexity 136.07
# | epoch 2 |  iter 1121 / 1327 | time 220[s] | perplexity 171.54
# | epoch 2 |  iter 1141 / 1327 | time 224[s] | perplexity 162.90
# | epoch 2 |  iter 1161 / 1327 | time 228[s] | perplexity 146.18
# | epoch 2 |  iter 1181 / 1327 | time 232[s] | perplexity 149.31
# | epoch 2 |  iter 1201 / 1327 | time 236[s] | perplexity 125.81
# | epoch 2 |  iter 1221 / 1327 | time 240[s] | perplexity 123.41
# | epoch 2 |  iter 1241 / 1327 | time 244[s] | perplexity 146.82
# | epoch 2 |  iter 1261 / 1327 | time 248[s] | perplexity 137.85
# | epoch 2 |  iter 1281 / 1327 | time 252[s] | perplexity 140.24
# | epoch 2 |  iter 1301 / 1327 | time 256[s] | perplexity 178.37
# | epoch 2 |  iter 1321 / 1327 | time 259[s] | perplexity 169.13
# evaluating perplexity ...
# 209 / 210
# valid perplexity:  146.41994
# --------------------------------------------------
#   0%|          | 0/1327 [00:00<?, ?it/s]
# | epoch 3 |  iter 1 / 1327 | time 0[s] | perplexity 216.56
# | epoch 3 |  iter 21 / 1327 | time 4[s] | perplexity 160.60
# | epoch 3 |  iter 41 / 1327 | time 7[s] | perplexity 151.42
# | epoch 3 |  iter 61 / 1327 | time 12[s] | perplexity 142.97
# | epoch 3 |  iter 81 / 1327 | time 16[s] | perplexity 127.64
# | epoch 3 |  iter 101 / 1327 | time 19[s] | perplexity 120.93
# | epoch 3 |  iter 121 / 1327 | time 24[s] | perplexity 132.56
# | epoch 3 |  iter 141 / 1327 | time 28[s] | perplexity 145.33
# | epoch 3 |  iter 161 / 1327 | time 31[s] | perplexity 160.57
# | epoch 3 |  iter 181 / 1327 | time 36[s] | perplexity 169.42
# | epoch 3 |  iter 201 / 1327 | time 40[s] | perplexity 159.00
# | epoch 3 |  iter 221 / 1327 | time 44[s] | perplexity 155.29
# | epoch 3 |  iter 241 / 1327 | time 48[s] | perplexity 149.94
# | epoch 3 |  iter 261 / 1327 | time 52[s] | perplexity 162.42
# | epoch 3 |  iter 281 / 1327 | time 56[s] | perplexity 158.69
# | epoch 3 |  iter 301 / 1327 | time 60[s] | perplexity 139.90
# | epoch 3 |  iter 321 / 1327 | time 64[s] | perplexity 111.12
# | epoch 3 |  iter 341 / 1327 | time 68[s] | perplexity 152.46
# | epoch 3 |  iter 361 / 1327 | time 72[s] | perplexity 163.83
# | epoch 3 |  iter 381 / 1327 | time 76[s] | perplexity 130.29
# | epoch 3 |  iter 401 / 1327 | time 79[s] | perplexity 150.07
# | epoch 3 |  iter 421 / 1327 | time 84[s] | perplexity 131.20
# | epoch 3 |  iter 441 / 1327 | time 88[s] | perplexity 138.31
# | epoch 3 |  iter 461 / 1327 | time 91[s] | perplexity 139.16
# | epoch 3 |  iter 481 / 1327 | time 95[s] | perplexity 134.34
# | epoch 3 |  iter 501 / 1327 | time 99[s] | perplexity 149.86
# | epoch 3 |  iter 521 / 1327 | time 103[s] | perplexity 151.59
# | epoch 3 |  iter 541 / 1327 | time 107[s] | perplexity 157.23
# | epoch 3 |  iter 561 / 1327 | time 111[s] | perplexity 132.25
# | epoch 3 |  iter 581 / 1327 | time 115[s] | perplexity 122.00
# | epoch 3 |  iter 601 / 1327 | time 119[s] | perplexity 169.21
# | epoch 3 |  iter 621 / 1327 | time 123[s] | perplexity 158.36
# | epoch 3 |  iter 641 / 1327 | time 127[s] | perplexity 145.02
# | epoch 3 |  iter 661 / 1327 | time 131[s] | perplexity 135.24
# | epoch 3 |  iter 681 / 1327 | time 135[s] | perplexity 116.34
# | epoch 3 |  iter 701 / 1327 | time 139[s] | perplexity 136.16
# | epoch 3 |  iter 721 / 1327 | time 142[s] | perplexity 138.85
# | epoch 3 |  iter 741 / 1327 | time 147[s] | perplexity 118.80
# | epoch 3 |  iter 761 / 1327 | time 150[s] | perplexity 113.15
# | epoch 3 |  iter 781 / 1327 | time 154[s] | perplexity 119.58
# | epoch 3 |  iter 801 / 1327 | time 158[s] | perplexity 134.24
# | epoch 3 |  iter 821 / 1327 | time 162[s] | perplexity 132.81
# | epoch 3 |  iter 841 / 1327 | time 166[s] | perplexity 132.47
# | epoch 3 |  iter 861 / 1327 | time 170[s] | perplexity 128.91
# | epoch 3 |  iter 881 / 1327 | time 174[s] | perplexity 119.56
# | epoch 3 |  iter 901 / 1327 | time 178[s] | perplexity 151.80
# | epoch 3 |  iter 921 / 1327 | time 182[s] | perplexity 133.28
# | epoch 3 |  iter 941 / 1327 | time 186[s] | perplexity 138.66
# | epoch 3 |  iter 961 / 1327 | time 190[s] | perplexity 151.28
# | epoch 3 |  iter 981 / 1327 | time 194[s] | perplexity 142.29
# | epoch 3 |  iter 1001 / 1327 | time 198[s] | perplexity 122.72
# | epoch 3 |  iter 1021 / 1327 | time 202[s] | perplexity 146.70
# | epoch 3 |  iter 1041 / 1327 | time 206[s] | perplexity 129.38
# | epoch 3 |  iter 1061 / 1327 | time 210[s] | perplexity 119.61
# | epoch 3 |  iter 1081 / 1327 | time 214[s] | perplexity 100.12
# | epoch 3 |  iter 1101 / 1327 | time 217[s] | perplexity 106.52
# | epoch 3 |  iter 1121 / 1327 | time 222[s] | perplexity 140.71
# | epoch 3 |  iter 1141 / 1327 | time 226[s] | perplexity 134.23
# | epoch 3 |  iter 1161 / 1327 | time 229[s] | perplexity 116.53
# | epoch 3 |  iter 1181 / 1327 | time 234[s] | perplexity 123.25
# | epoch 3 |  iter 1201 / 1327 | time 237[s] | perplexity 104.24
# | epoch 3 |  iter 1221 / 1327 | time 241[s] | perplexity 103.21
# | epoch 3 |  iter 1241 / 1327 | time 245[s] | perplexity 121.22
# | epoch 3 |  iter 1261 / 1327 | time 249[s] | perplexity 114.78
# | epoch 3 |  iter 1281 / 1327 | time 253[s] | perplexity 115.59
# | epoch 3 |  iter 1301 / 1327 | time 257[s] | perplexity 147.45
# | epoch 3 |  iter 1321 / 1327 | time 261[s] | perplexity 142.20
# evaluating perplexity ...
# 209 / 210
# valid perplexity:  124.398384
# --------------------------------------------------
#   0%|          | 0/1327 [00:00<?, ?it/s]
# | epoch 4 |  iter 1 / 1327 | time 0[s] | perplexity 185.54
# | epoch 4 |  iter 21 / 1327 | time 4[s] | perplexity 128.99
# | epoch 4 |  iter 41 / 1327 | time 8[s] | perplexity 123.87
# | epoch 4 |  iter 61 / 1327 | time 12[s] | perplexity 117.25
# | epoch 4 |  iter 81 / 1327 | time 15[s] | perplexity 104.20
# | epoch 4 |  iter 101 / 1327 | time 20[s] | perplexity 99.13
# | epoch 4 |  iter 121 / 1327 | time 23[s] | perplexity 109.79
# | epoch 4 |  iter 141 / 1327 | time 27[s] | perplexity 120.21
# | epoch 4 |  iter 161 / 1327 | time 32[s] | perplexity 136.41
# | epoch 4 |  iter 181 / 1327 | time 36[s] | perplexity 143.96
# | epoch 4 |  iter 201 / 1327 | time 39[s] | perplexity 136.82
# | epoch 4 |  iter 221 / 1327 | time 44[s] | perplexity 132.29
# | epoch 4 |  iter 241 / 1327 | time 47[s] | perplexity 126.67
# | epoch 4 |  iter 261 / 1327 | time 51[s] | perplexity 139.01
# | epoch 4 |  iter 281 / 1327 | time 56[s] | perplexity 133.16
# | epoch 4 |  iter 301 / 1327 | time 59[s] | perplexity 115.41
# | epoch 4 |  iter 321 / 1327 | time 63[s] | perplexity 91.13
# | epoch 4 |  iter 341 / 1327 | time 68[s] | perplexity 128.41
# | epoch 4 |  iter 361 / 1327 | time 71[s] | perplexity 137.87
# | epoch 4 |  iter 381 / 1327 | time 75[s] | perplexity 110.99
# | epoch 4 |  iter 401 / 1327 | time 79[s] | perplexity 127.46
# | epoch 4 |  iter 421 / 1327 | time 83[s] | perplexity 108.36
# | epoch 4 |  iter 441 / 1327 | time 87[s] | perplexity 118.34
# | epoch 4 |  iter 461 / 1327 | time 91[s] | perplexity 116.16
# | epoch 4 |  iter 481 / 1327 | time 95[s] | perplexity 115.21
# | epoch 4 |  iter 501 / 1327 | time 99[s] | perplexity 128.19
# | epoch 4 |  iter 521 / 1327 | time 103[s] | perplexity 130.37
# | epoch 4 |  iter 541 / 1327 | time 108[s] | perplexity 132.77
# | epoch 4 |  iter 561 / 1327 | time 111[s] | perplexity 112.49
# | epoch 4 |  iter 581 / 1327 | time 115[s] | perplexity 104.17
# | epoch 4 |  iter 601 / 1327 | time 119[s] | perplexity 145.61
# | epoch 4 |  iter 621 / 1327 | time 123[s] | perplexity 137.64
# | epoch 4 |  iter 641 / 1327 | time 127[s] | perplexity 124.54
# | epoch 4 |  iter 661 / 1327 | time 131[s] | perplexity 115.54
# | epoch 4 |  iter 681 / 1327 | time 135[s] | perplexity 99.65
# | epoch 4 |  iter 701 / 1327 | time 139[s] | perplexity 116.78
# | epoch 4 |  iter 721 / 1327 | time 143[s] | perplexity 118.95
# | epoch 4 |  iter 741 / 1327 | time 147[s] | perplexity 102.19
# | epoch 4 |  iter 761 / 1327 | time 151[s] | perplexity 95.90
# | epoch 4 |  iter 781 / 1327 | time 155[s] | perplexity 103.01
# | epoch 4 |  iter 801 / 1327 | time 159[s] | perplexity 117.82
# | epoch 4 |  iter 821 / 1327 | time 163[s] | perplexity 115.52
# | epoch 4 |  iter 841 / 1327 | time 167[s] | perplexity 114.32
# | epoch 4 |  iter 861 / 1327 | time 171[s] | perplexity 112.47
# | epoch 4 |  iter 881 / 1327 | time 175[s] | perplexity 103.99
# | epoch 4 |  iter 901 / 1327 | time 178[s] | perplexity 132.22
# | epoch 4 |  iter 921 / 1327 | time 183[s] | perplexity 116.66
# | epoch 4 |  iter 941 / 1327 | time 186[s] | perplexity 122.83
# | epoch 4 |  iter 961 / 1327 | time 190[s] | perplexity 132.85
# | epoch 4 |  iter 981 / 1327 | time 195[s] | perplexity 126.06
# | epoch 4 |  iter 1001 / 1327 | time 198[s] | perplexity 105.92
# | epoch 4 |  iter 1021 / 1327 | time 202[s] | perplexity 128.01
# | epoch 4 |  iter 1041 / 1327 | time 206[s] | perplexity 110.66
# | epoch 4 |  iter 1061 / 1327 | time 210[s] | perplexity 104.64
# | epoch 4 |  iter 1081 / 1327 | time 214[s] | perplexity 87.84
# | epoch 4 |  iter 1101 / 1327 | time 218[s] | perplexity 89.90
# | epoch 4 |  iter 1121 / 1327 | time 222[s] | perplexity 122.17
# | epoch 4 |  iter 1141 / 1327 | time 226[s] | perplexity 116.30
# | epoch 4 |  iter 1161 / 1327 | time 230[s] | perplexity 100.97
# | epoch 4 |  iter 1181 / 1327 | time 234[s] | perplexity 108.19
# | epoch 4 |  iter 1201 / 1327 | time 238[s] | perplexity 90.35
# | epoch 4 |  iter 1221 / 1327 | time 242[s] | perplexity 91.00
# | epoch 4 |  iter 1241 / 1327 | time 246[s] | perplexity 107.87
# | epoch 4 |  iter 1261 / 1327 | time 250[s] | perplexity 101.14
# | epoch 4 |  iter 1281 / 1327 | time 254[s] | perplexity 101.66
# | epoch 4 |  iter 1301 / 1327 | time 258[s] | perplexity 129.54
# | epoch 4 |  iter 1321 / 1327 | time 262[s] | perplexity 126.69
# evaluating perplexity ...
# 209 / 210
# valid perplexity:  110.595116
# --------------------------------------------------
#   0%|          | 0/1327 [00:00<?, ?it/s]
# | epoch 5 |  iter 1 / 1327 | time 0[s] | perplexity 175.20
# | epoch 5 |  iter 21 / 1327 | time 4[s] | perplexity 113.08
# | epoch 5 |  iter 41 / 1327 | time 8[s] | perplexity 108.83
# | epoch 5 |  iter 61 / 1327 | time 12[s] | perplexity 103.60
# | epoch 5 |  iter 81 / 1327 | time 16[s] | perplexity 93.15
# | epoch 5 |  iter 101 / 1327 | time 19[s] | perplexity 86.11
# | epoch 5 |  iter 121 / 1327 | time 23[s] | perplexity 97.22
# | epoch 5 |  iter 141 / 1327 | time 28[s] | perplexity 104.80
# | epoch 5 |  iter 161 / 1327 | time 31[s] | perplexity 119.11
# | epoch 5 |  iter 181 / 1327 | time 35[s] | perplexity 126.46
# | epoch 5 |  iter 201 / 1327 | time 39[s] | perplexity 121.99
# | epoch 5 |  iter 221 / 1327 | time 43[s] | perplexity 119.66
# | epoch 5 |  iter 241 / 1327 | time 47[s] | perplexity 112.48
# | epoch 5 |  iter 261 / 1327 | time 51[s] | perplexity 122.20
# | epoch 5 |  iter 281 / 1327 | time 55[s] | perplexity 118.63
# | epoch 5 |  iter 301 / 1327 | time 59[s] | perplexity 100.47
# | epoch 5 |  iter 321 / 1327 | time 63[s] | perplexity 79.99
# | epoch 5 |  iter 341 / 1327 | time 67[s] | perplexity 112.96
# | epoch 5 |  iter 361 / 1327 | time 71[s] | perplexity 121.14
# | epoch 5 |  iter 381 / 1327 | time 75[s] | perplexity 98.74
# | epoch 5 |  iter 401 / 1327 | time 79[s] | perplexity 112.46
# | epoch 5 |  iter 421 / 1327 | time 83[s] | perplexity 96.37
# | epoch 5 |  iter 441 / 1327 | time 87[s] | perplexity 104.86
# | epoch 5 |  iter 461 / 1327 | time 91[s] | perplexity 104.31
# | epoch 5 |  iter 481 / 1327 | time 95[s] | perplexity 102.82
# | epoch 5 |  iter 501 / 1327 | time 99[s] | perplexity 113.47
# | epoch 5 |  iter 521 / 1327 | time 103[s] | perplexity 118.01
# | epoch 5 |  iter 541 / 1327 | time 107[s] | perplexity 118.55
# | epoch 5 |  iter 561 / 1327 | time 110[s] | perplexity 100.95
# | epoch 5 |  iter 581 / 1327 | time 115[s] | perplexity 93.69
# | epoch 5 |  iter 601 / 1327 | time 119[s] | perplexity 130.64
# | epoch 5 |  iter 621 / 1327 | time 122[s] | perplexity 120.04
# | epoch 5 |  iter 641 / 1327 | time 127[s] | perplexity 113.71
# | epoch 5 |  iter 661 / 1327 | time 131[s] | perplexity 102.18
# | epoch 5 |  iter 681 / 1327 | time 134[s] | perplexity 88.69
# | epoch 5 |  iter 701 / 1327 | time 139[s] | perplexity 104.69
# | epoch 5 |  iter 721 / 1327 | time 143[s] | perplexity 106.67
# | epoch 5 |  iter 741 / 1327 | time 146[s] | perplexity 92.73
# | epoch 5 |  iter 761 / 1327 | time 151[s] | perplexity 85.78
# | epoch 5 |  iter 781 / 1327 | time 154[s] | perplexity 92.71
# | epoch 5 |  iter 801 / 1327 | time 158[s] | perplexity 106.50
# | epoch 5 |  iter 821 / 1327 | time 163[s] | perplexity 105.54
# | epoch 5 |  iter 841 / 1327 | time 166[s] | perplexity 103.17
# | epoch 5 |  iter 861 / 1327 | time 170[s] | perplexity 102.63
# | epoch 5 |  iter 881 / 1327 | time 174[s] | perplexity 94.17
# | epoch 5 |  iter 901 / 1327 | time 178[s] | perplexity 119.34
# | epoch 5 |  iter 921 / 1327 | time 182[s] | perplexity 104.80
# | epoch 5 |  iter 941 / 1327 | time 186[s] | perplexity 111.56
# | epoch 5 |  iter 961 / 1327 | time 190[s] | perplexity 120.95
# | epoch 5 |  iter 981 / 1327 | time 194[s] | perplexity 113.14
# | epoch 5 |  iter 1001 / 1327 | time 197[s] | perplexity 97.76
# | epoch 5 |  iter 1021 / 1327 | time 202[s] | perplexity 117.19
# | epoch 5 |  iter 1041 / 1327 | time 206[s] | perplexity 101.44
# | epoch 5 |  iter 1061 / 1327 | time 209[s] | perplexity 94.95
# | epoch 5 |  iter 1081 / 1327 | time 214[s] | perplexity 78.54
# | epoch 5 |  iter 1101 / 1327 | time 218[s] | perplexity 80.37
# | epoch 5 |  iter 1121 / 1327 | time 221[s] | perplexity 111.04
# | epoch 5 |  iter 1141 / 1327 | time 226[s] | perplexity 106.05
# | epoch 5 |  iter 1161 / 1327 | time 230[s] | perplexity 89.72
# | epoch 5 |  iter 1181 / 1327 | time 233[s] | perplexity 99.41
# | epoch 5 |  iter 1201 / 1327 | time 238[s] | perplexity 81.00
# | epoch 5 |  iter 1221 / 1327 | time 241[s] | perplexity 81.54
# | epoch 5 |  iter 1241 / 1327 | time 245[s] | perplexity 98.35
# | epoch 5 |  iter 1261 / 1327 | time 250[s] | perplexity 92.91
# | epoch 5 |  iter 1281 / 1327 | time 253[s] | perplexity 92.32
# | epoch 5 |  iter 1301 / 1327 | time 257[s] | perplexity 118.03
# | epoch 5 |  iter 1321 / 1327 | time 261[s] | perplexity 114.70
# evaluating perplexity ...
# 209 / 210
# valid perplexity:  104.328835
# --------------------------------------------------
#   0%|          | 0/1327 [00:00<?, ?it/s]
# | epoch 6 |  iter 1 / 1327 | time 0[s] | perplexity 149.11
# | epoch 6 |  iter 21 / 1327 | time 3[s] | perplexity 101.29
# | epoch 6 |  iter 41 / 1327 | time 8[s] | perplexity 99.08
# | epoch 6 |  iter 61 / 1327 | time 11[s] | perplexity 95.55
# | epoch 6 |  iter 81 / 1327 | time 15[s] | perplexity 83.80
# | epoch 6 |  iter 101 / 1327 | time 19[s] | perplexity 79.51
# | epoch 6 |  iter 121 / 1327 | time 23[s] | perplexity 87.23
# | epoch 6 |  iter 141 / 1327 | time 27[s] | perplexity 95.28
# | epoch 6 |  iter 161 / 1327 | time 31[s] | perplexity 110.08
# | epoch 6 |  iter 181 / 1327 | time 35[s] | perplexity 117.92
# | epoch 6 |  iter 201 / 1327 | time 39[s] | perplexity 113.34
# | epoch 6 |  iter 221 / 1327 | time 43[s] | perplexity 109.24
# | epoch 6 |  iter 241 / 1327 | time 47[s] | perplexity 102.41
# | epoch 6 |  iter 261 / 1327 | time 51[s] | perplexity 112.03
# | epoch 6 |  iter 281 / 1327 | time 55[s] | perplexity 110.30
# | epoch 6 |  iter 301 / 1327 | time 59[s] | perplexity 92.13
# | epoch 6 |  iter 321 / 1327 | time 63[s] | perplexity 73.21
# | epoch 6 |  iter 341 / 1327 | time 67[s] | perplexity 104.86
# | epoch 6 |  iter 361 / 1327 | time 71[s] | perplexity 110.53
# | epoch 6 |  iter 381 / 1327 | time 75[s] | perplexity 91.04
# | epoch 6 |  iter 401 / 1327 | time 79[s] | perplexity 103.73
# | epoch 6 |  iter 421 / 1327 | time 83[s] | perplexity 88.29
# | epoch 6 |  iter 441 / 1327 | time 87[s] | perplexity 95.54
# | epoch 6 |  iter 461 / 1327 | time 91[s] | perplexity 94.86
# | epoch 6 |  iter 481 / 1327 | time 95[s] | perplexity 94.24
# | epoch 6 |  iter 501 / 1327 | time 99[s] | perplexity 105.04
# | epoch 6 |  iter 521 / 1327 | time 103[s] | perplexity 107.82
# | epoch 6 |  iter 541 / 1327 | time 107[s] | perplexity 108.38
# | epoch 6 |  iter 561 / 1327 | time 111[s] | perplexity 91.41
# | epoch 6 |  iter 581 / 1327 | time 115[s] | perplexity 85.18
# | epoch 6 |  iter 601 / 1327 | time 119[s] | perplexity 119.30
# | epoch 6 |  iter 621 / 1327 | time 123[s] | perplexity 111.16
# | epoch 6 |  iter 641 / 1327 | time 127[s] | perplexity 103.51
# | epoch 6 |  iter 661 / 1327 | time 131[s] | perplexity 95.27
# | epoch 6 |  iter 681 / 1327 | time 135[s] | perplexity 81.25
# | epoch 6 |  iter 701 / 1327 | time 139[s] | perplexity 97.32
# | epoch 6 |  iter 721 / 1327 | time 142[s] | perplexity 97.33
# | epoch 6 |  iter 741 / 1327 | time 147[s] | perplexity 84.46
# | epoch 6 |  iter 761 / 1327 | time 151[s] | perplexity 78.41
# | epoch 6 |  iter 781 / 1327 | time 154[s] | perplexity 85.12
# | epoch 6 |  iter 801 / 1327 | time 159[s] | perplexity 97.29
# | epoch 6 |  iter 821 / 1327 | time 163[s] | perplexity 96.75
# | epoch 6 |  iter 841 / 1327 | time 166[s] | perplexity 96.05
# | epoch 6 |  iter 861 / 1327 | time 171[s] | perplexity 94.98
# | epoch 6 |  iter 881 / 1327 | time 175[s] | perplexity 87.84
# | epoch 6 |  iter 901 / 1327 | time 178[s] | perplexity 112.02
# | epoch 6 |  iter 921 / 1327 | time 183[s] | perplexity 96.59
# | epoch 6 |  iter 941 / 1327 | time 187[s] | perplexity 104.18
# | epoch 6 |  iter 961 / 1327 | time 190[s] | perplexity 111.51
# | epoch 6 |  iter 981 / 1327 | time 195[s] | perplexity 105.66
# | epoch 6 |  iter 1001 / 1327 | time 198[s] | perplexity 91.32
# | epoch 6 |  iter 1021 / 1327 | time 202[s] | perplexity 107.16
# | epoch 6 |  iter 1041 / 1327 | time 206[s] | perplexity 92.46
# | epoch 6 |  iter 1061 / 1327 | time 210[s] | perplexity 89.04
# | epoch 6 |  iter 1081 / 1327 | time 214[s] | perplexity 73.04
# | epoch 6 |  iter 1101 / 1327 | time 218[s] | perplexity 74.36
# | epoch 6 |  iter 1121 / 1327 | time 222[s] | perplexity 103.17
# | epoch 6 |  iter 1141 / 1327 | time 226[s] | perplexity 97.96
# | epoch 6 |  iter 1161 / 1327 | time 230[s] | perplexity 82.88
# | epoch 6 |  iter 1181 / 1327 | time 234[s] | perplexity 92.03
# | epoch 6 |  iter 1201 / 1327 | time 238[s] | perplexity 75.36
# | epoch 6 |  iter 1221 / 1327 | time 241[s] | perplexity 76.90
# | epoch 6 |  iter 1241 / 1327 | time 246[s] | perplexity 91.33
# | epoch 6 |  iter 1261 / 1327 | time 250[s] | perplexity 87.20
# | epoch 6 |  iter 1281 / 1327 | time 253[s] | perplexity 85.12
# | epoch 6 |  iter 1301 / 1327 | time 258[s] | perplexity 108.98
# | epoch 6 |  iter 1321 / 1327 | time 262[s] | perplexity 107.92
# evaluating perplexity ...
# 209 / 210
# valid perplexity:  99.65527
# --------------------------------------------------
#   0%|          | 0/1327 [00:00<?, ?it/s]
# | epoch 7 |  iter 1 / 1327 | time 0[s] | perplexity 145.79
# | epoch 7 |  iter 21 / 1327 | time 4[s] | perplexity 94.24
# | epoch 7 |  iter 41 / 1327 | time 8[s] | perplexity 92.30
# | epoch 7 |  iter 61 / 1327 | time 11[s] | perplexity 88.62
# | epoch 7 |  iter 81 / 1327 | time 16[s] | perplexity 77.73
# | epoch 7 |  iter 101 / 1327 | time 20[s] | perplexity 74.46
# | epoch 7 |  iter 121 / 1327 | time 23[s] | perplexity 82.49
# | epoch 7 |  iter 141 / 1327 | time 28[s] | perplexity 88.06
# | epoch 7 |  iter 161 / 1327 | time 32[s] | perplexity 102.63
# | epoch 7 |  iter 181 / 1327 | time 36[s] | perplexity 108.85
# | epoch 7 |  iter 201 / 1327 | time 40[s] | perplexity 105.81
# | epoch 7 |  iter 221 / 1327 | time 44[s] | perplexity 100.35
# | epoch 7 |  iter 241 / 1327 | time 47[s] | perplexity 96.53
# | epoch 7 |  iter 261 / 1327 | time 51[s] | perplexity 104.36
# | epoch 7 |  iter 281 / 1327 | time 55[s] | perplexity 101.55
# | epoch 7 |  iter 301 / 1327 | time 59[s] | perplexity 84.39
# | epoch 7 |  iter 321 / 1327 | time 63[s] | perplexity 68.11
# | epoch 7 |  iter 341 / 1327 | time 67[s] | perplexity 97.35
# | epoch 7 |  iter 361 / 1327 | time 71[s] | perplexity 103.59
# | epoch 7 |  iter 381 / 1327 | time 75[s] | perplexity 84.56
# | epoch 7 |  iter 401 / 1327 | time 79[s] | perplexity 96.96
# | epoch 7 |  iter 421 / 1327 | time 83[s] | perplexity 82.60
# | epoch 7 |  iter 441 / 1327 | time 87[s] | perplexity 88.22
# | epoch 7 |  iter 461 / 1327 | time 91[s] | perplexity 88.89
# | epoch 7 |  iter 481 / 1327 | time 95[s] | perplexity 88.27
# | epoch 7 |  iter 501 / 1327 | time 99[s] | perplexity 98.39
# | epoch 7 |  iter 521 / 1327 | time 103[s] | perplexity 102.13
# | epoch 7 |  iter 541 / 1327 | time 107[s] | perplexity 101.73
# | epoch 7 |  iter 561 / 1327 | time 110[s] | perplexity 85.81
# | epoch 7 |  iter 581 / 1327 | time 115[s] | perplexity 78.60
# | epoch 7 |  iter 601 / 1327 | time 119[s] | perplexity 112.33
# | epoch 7 |  iter 621 / 1327 | time 123[s] | perplexity 104.06
# | epoch 7 |  iter 641 / 1327 | time 127[s] | perplexity 97.40
# | epoch 7 |  iter 661 / 1327 | time 131[s] | perplexity 87.37
# | epoch 7 |  iter 681 / 1327 | time 134[s] | perplexity 77.63
# | epoch 7 |  iter 701 / 1327 | time 138[s] | perplexity 91.53
# | epoch 7 |  iter 721 / 1327 | time 143[s] | perplexity 92.27
# | epoch 7 |  iter 741 / 1327 | time 146[s] | perplexity 80.38
# | epoch 7 |  iter 761 / 1327 | time 150[s] | perplexity 72.86
# | epoch 7 |  iter 781 / 1327 | time 154[s] | perplexity 80.96
# | epoch 7 |  iter 801 / 1327 | time 158[s] | perplexity 91.02
# | epoch 7 |  iter 821 / 1327 | time 162[s] | perplexity 91.45
# | epoch 7 |  iter 841 / 1327 | time 166[s] | perplexity 90.16
# | epoch 7 |  iter 861 / 1327 | time 170[s] | perplexity 89.54
# | epoch 7 |  iter 881 / 1327 | time 174[s] | perplexity 82.44
# | epoch 7 |  iter 901 / 1327 | time 178[s] | perplexity 103.78
# | epoch 7 |  iter 921 / 1327 | time 182[s] | perplexity 92.51
# | epoch 7 |  iter 941 / 1327 | time 186[s] | perplexity 98.71
# | epoch 7 |  iter 961 / 1327 | time 190[s] | perplexity 104.34
# | epoch 7 |  iter 981 / 1327 | time 194[s] | perplexity 100.18
# | epoch 7 |  iter 1001 / 1327 | time 197[s] | perplexity 85.77
# | epoch 7 |  iter 1021 / 1327 | time 201[s] | perplexity 101.07
# | epoch 7 |  iter 1041 / 1327 | time 205[s] | perplexity 87.28
# | epoch 7 |  iter 1061 / 1327 | time 209[s] | perplexity 81.88
# | epoch 7 |  iter 1081 / 1327 | time 213[s] | perplexity 67.89
# | epoch 7 |  iter 1101 / 1327 | time 217[s] | perplexity 70.17
# | epoch 7 |  iter 1121 / 1327 | time 221[s] | perplexity 95.31
# | epoch 7 |  iter 1141 / 1327 | time 225[s] | perplexity 91.56
# | epoch 7 |  iter 1161 / 1327 | time 229[s] | perplexity 77.04
# | epoch 7 |  iter 1181 / 1327 | time 233[s] | perplexity 85.88
# | epoch 7 |  iter 1201 / 1327 | time 237[s] | perplexity 71.10
# | epoch 7 |  iter 1221 / 1327 | time 241[s] | perplexity 71.23
# | epoch 7 |  iter 1241 / 1327 | time 245[s] | perplexity 86.00
# | epoch 7 |  iter 1261 / 1327 | time 249[s] | perplexity 80.86
# | epoch 7 |  iter 1281 / 1327 | time 253[s] | perplexity 80.99
# | epoch 7 |  iter 1301 / 1327 | time 257[s] | perplexity 102.50
# | epoch 7 |  iter 1321 / 1327 | time 260[s] | perplexity 100.01
# evaluating perplexity ...
# 209 / 210
# valid perplexity:  96.31289
# --------------------------------------------------
#   0%|          | 0/1327 [00:00<?, ?it/s]
# | epoch 8 |  iter 1 / 1327 | time 0[s] | perplexity 140.51
# | epoch 8 |  iter 21 / 1327 | time 3[s] | perplexity 88.54
# | epoch 8 |  iter 41 / 1327 | time 7[s] | perplexity 86.13
# | epoch 8 |  iter 61 / 1327 | time 12[s] | perplexity 84.51
# | epoch 8 |  iter 81 / 1327 | time 15[s] | perplexity 73.92
# | epoch 8 |  iter 101 / 1327 | time 19[s] | perplexity 70.09
# | epoch 8 |  iter 121 / 1327 | time 24[s] | perplexity 77.43
# | epoch 8 |  iter 141 / 1327 | time 27[s] | perplexity 82.99
# | epoch 8 |  iter 161 / 1327 | time 31[s] | perplexity 96.24
# | epoch 8 |  iter 181 / 1327 | time 35[s] | perplexity 103.77
# | epoch 8 |  iter 201 / 1327 | time 39[s] | perplexity 99.71
# | epoch 8 |  iter 221 / 1327 | time 43[s] | perplexity 97.96
# | epoch 8 |  iter 241 / 1327 | time 47[s] | perplexity 91.34
# | epoch 8 |  iter 261 / 1327 | time 51[s] | perplexity 98.46
# | epoch 8 |  iter 281 / 1327 | time 55[s] | perplexity 95.58
# | epoch 8 |  iter 301 / 1327 | time 59[s] | perplexity 80.14
# | epoch 8 |  iter 321 / 1327 | time 63[s] | perplexity 65.27
# | epoch 8 |  iter 341 / 1327 | time 67[s] | perplexity 92.30
# | epoch 8 |  iter 361 / 1327 | time 70[s] | perplexity 95.80
# | epoch 8 |  iter 381 / 1327 | time 75[s] | perplexity 80.69
# | epoch 8 |  iter 401 / 1327 | time 78[s] | perplexity 91.32
# | epoch 8 |  iter 421 / 1327 | time 82[s] | perplexity 77.60
# | epoch 8 |  iter 441 / 1327 | time 87[s] | perplexity 84.78
# | epoch 8 |  iter 461 / 1327 | time 90[s] | perplexity 84.20
# | epoch 8 |  iter 481 / 1327 | time 94[s] | perplexity 83.89
# | epoch 8 |  iter 501 / 1327 | time 99[s] | perplexity 92.01
# | epoch 8 |  iter 521 / 1327 | time 102[s] | perplexity 96.42
# | epoch 8 |  iter 541 / 1327 | time 106[s] | perplexity 95.68
# | epoch 8 |  iter 561 / 1327 | time 111[s] | perplexity 80.88
# | epoch 8 |  iter 581 / 1327 | time 114[s] | perplexity 75.05
# | epoch 8 |  iter 601 / 1327 | time 118[s] | perplexity 106.74
# | epoch 8 |  iter 621 / 1327 | time 122[s] | perplexity 98.70
# | epoch 8 |  iter 641 / 1327 | time 126[s] | perplexity 90.87
# | epoch 8 |  iter 661 / 1327 | time 130[s] | perplexity 82.40
# | epoch 8 |  iter 681 / 1327 | time 134[s] | perplexity 73.10
# | epoch 8 |  iter 701 / 1327 | time 138[s] | perplexity 85.20
# | epoch 8 |  iter 721 / 1327 | time 142[s] | perplexity 86.91
# | epoch 8 |  iter 741 / 1327 | time 146[s] | perplexity 76.05
# | epoch 8 |  iter 761 / 1327 | time 150[s] | perplexity 70.17
# | epoch 8 |  iter 781 / 1327 | time 154[s] | perplexity 76.83
# | epoch 8 |  iter 801 / 1327 | time 157[s] | perplexity 86.04
# | epoch 8 |  iter 821 / 1327 | time 162[s] | perplexity 86.15
# | epoch 8 |  iter 841 / 1327 | time 166[s] | perplexity 86.23
# | epoch 8 |  iter 861 / 1327 | time 169[s] | perplexity 85.77
# | epoch 8 |  iter 881 / 1327 | time 174[s] | perplexity 78.30
# | epoch 8 |  iter 901 / 1327 | time 177[s] | perplexity 98.22
# | epoch 8 |  iter 921 / 1327 | time 181[s] | perplexity 87.13
# | epoch 8 |  iter 941 / 1327 | time 186[s] | perplexity 92.94
# | epoch 8 |  iter 961 / 1327 | time 190[s] | perplexity 99.49
# | epoch 8 |  iter 981 / 1327 | time 193[s] | perplexity 94.65
# | epoch 8 |  iter 1001 / 1327 | time 197[s] | perplexity 81.61
# | epoch 8 |  iter 1021 / 1327 | time 201[s] | perplexity 96.66
# | epoch 8 |  iter 1041 / 1327 | time 205[s] | perplexity 83.16
# | epoch 8 |  iter 1061 / 1327 | time 209[s] | perplexity 78.61
# | epoch 8 |  iter 1081 / 1327 | time 213[s] | perplexity 65.59
# | epoch 8 |  iter 1101 / 1327 | time 217[s] | perplexity 67.13
# | epoch 8 |  iter 1121 / 1327 | time 221[s] | perplexity 91.25
# | epoch 8 |  iter 1141 / 1327 | time 225[s] | perplexity 87.04
# | epoch 8 |  iter 1161 / 1327 | time 229[s] | perplexity 73.70
# | epoch 8 |  iter 1181 / 1327 | time 233[s] | perplexity 81.41
# | epoch 8 |  iter 1201 / 1327 | time 237[s] | perplexity 68.29
# | epoch 8 |  iter 1221 / 1327 | time 241[s] | perplexity 67.86
# | epoch 8 |  iter 1241 / 1327 | time 245[s] | perplexity 81.66
# | epoch 8 |  iter 1261 / 1327 | time 249[s] | perplexity 77.36
# | epoch 8 |  iter 1281 / 1327 | time 253[s] | perplexity 77.61
# | epoch 8 |  iter 1301 / 1327 | time 256[s] | perplexity 98.13
# | epoch 8 |  iter 1321 / 1327 | time 261[s] | perplexity 94.60
# evaluating perplexity ...
# 209 / 210
# valid perplexity:  94.40554
# --------------------------------------------------
#   0%|          | 0/1327 [00:00<?, ?it/s]
# | epoch 9 |  iter 1 / 1327 | time 0[s] | perplexity 136.27
# | epoch 9 |  iter 21 / 1327 | time 3[s] | perplexity 85.53
# | epoch 9 |  iter 41 / 1327 | time 8[s] | perplexity 82.16
# | epoch 9 |  iter 61 / 1327 | time 12[s] | perplexity 80.81
# | epoch 9 |  iter 81 / 1327 | time 15[s] | perplexity 68.96
# | epoch 9 |  iter 101 / 1327 | time 20[s] | perplexity 66.86
# | epoch 9 |  iter 121 / 1327 | time 23[s] | perplexity 72.74
# | epoch 9 |  iter 141 / 1327 | time 27[s] | perplexity 78.68
# | epoch 9 |  iter 161 / 1327 | time 32[s] | perplexity 91.25
# | epoch 9 |  iter 181 / 1327 | time 35[s] | perplexity 99.04
# | epoch 9 |  iter 201 / 1327 | time 39[s] | perplexity 96.32
# | epoch 9 |  iter 221 / 1327 | time 43[s] | perplexity 92.64
# | epoch 9 |  iter 241 / 1327 | time 47[s] | perplexity 86.87
# | epoch 9 |  iter 261 / 1327 | time 51[s] | perplexity 93.71
# | epoch 9 |  iter 281 / 1327 | time 55[s] | perplexity 91.33
# | epoch 9 |  iter 301 / 1327 | time 59[s] | perplexity 76.16
# | epoch 9 |  iter 321 / 1327 | time 63[s] | perplexity 62.03
# | epoch 9 |  iter 341 / 1327 | time 67[s] | perplexity 88.33
# | epoch 9 |  iter 361 / 1327 | time 71[s] | perplexity 92.62
# | epoch 9 |  iter 381 / 1327 | time 75[s] | perplexity 77.57
# | epoch 9 |  iter 401 / 1327 | time 79[s] | perplexity 86.86
# | epoch 9 |  iter 421 / 1327 | time 83[s] | perplexity 75.08
# | epoch 9 |  iter 441 / 1327 | time 87[s] | perplexity 81.43
# | epoch 9 |  iter 461 / 1327 | time 91[s] | perplexity 80.29
# | epoch 9 |  iter 481 / 1327 | time 95[s] | perplexity 79.08
# | epoch 9 |  iter 501 / 1327 | time 99[s] | perplexity 87.65
# | epoch 9 |  iter 521 / 1327 | time 102[s] | perplexity 90.70
# | epoch 9 |  iter 541 / 1327 | time 107[s] | perplexity 91.82
# | epoch 9 |  iter 561 / 1327 | time 111[s] | perplexity 77.64
# | epoch 9 |  iter 581 / 1327 | time 114[s] | perplexity 71.41
# | epoch 9 |  iter 601 / 1327 | time 119[s] | perplexity 101.05
# | epoch 9 |  iter 621 / 1327 | time 123[s] | perplexity 93.61
# | epoch 9 |  iter 641 / 1327 | time 126[s] | perplexity 87.34
# | epoch 9 |  iter 661 / 1327 | time 130[s] | perplexity 79.71
# | epoch 9 |  iter 681 / 1327 | time 134[s] | perplexity 69.03
# | epoch 9 |  iter 701 / 1327 | time 138[s] | perplexity 82.26
# | epoch 9 |  iter 721 / 1327 | time 142[s] | perplexity 82.88
# | epoch 9 |  iter 741 / 1327 | time 146[s] | perplexity 71.79
# | epoch 9 |  iter 761 / 1327 | time 150[s] | perplexity 65.99
# | epoch 9 |  iter 781 / 1327 | time 154[s] | perplexity 73.41
# | epoch 9 |  iter 801 / 1327 | time 158[s] | perplexity 81.89
# | epoch 9 |  iter 821 / 1327 | time 162[s] | perplexity 82.23
# | epoch 9 |  iter 841 / 1327 | time 166[s] | perplexity 82.00
# | epoch 9 |  iter 861 / 1327 | time 170[s] | perplexity 82.00
# | epoch 9 |  iter 881 / 1327 | time 174[s] | perplexity 74.34
# | epoch 9 |  iter 901 / 1327 | time 177[s] | perplexity 94.32
# | epoch 9 |  iter 921 / 1327 | time 182[s] | perplexity 84.66
# | epoch 9 |  iter 941 / 1327 | time 186[s] | perplexity 89.89
# | epoch 9 |  iter 961 / 1327 | time 189[s] | perplexity 93.82
# | epoch 9 |  iter 981 / 1327 | time 193[s] | perplexity 90.72
# | epoch 9 |  iter 1001 / 1327 | time 197[s] | perplexity 78.67
# | epoch 9 |  iter 1021 / 1327 | time 201[s] | perplexity 91.92
# | epoch 9 |  iter 1041 / 1327 | time 205[s] | perplexity 79.11
# | epoch 9 |  iter 1061 / 1327 | time 209[s] | perplexity 75.37
# | epoch 9 |  iter 1081 / 1327 | time 213[s] | perplexity 61.87
# | epoch 9 |  iter 1101 / 1327 | time 217[s] | perplexity 63.06
# | epoch 9 |  iter 1121 / 1327 | time 221[s] | perplexity 86.91
# | epoch 9 |  iter 1141 / 1327 | time 225[s] | perplexity 82.54
# | epoch 9 |  iter 1161 / 1327 | time 228[s] | perplexity 70.42
# | epoch 9 |  iter 1181 / 1327 | time 233[s] | perplexity 77.83
# | epoch 9 |  iter 1201 / 1327 | time 237[s] | perplexity 66.11
# | epoch 9 |  iter 1221 / 1327 | time 240[s] | perplexity 64.65
# | epoch 9 |  iter 1241 / 1327 | time 245[s] | perplexity 78.83
# | epoch 9 |  iter 1261 / 1327 | time 249[s] | perplexity 73.86
# | epoch 9 |  iter 1281 / 1327 | time 252[s] | perplexity 73.77
# | epoch 9 |  iter 1301 / 1327 | time 257[s] | perplexity 93.76
# | epoch 9 |  iter 1321 / 1327 | time 260[s] | perplexity 91.55
# evaluating perplexity ...
# 209 / 210
# valid perplexity:  92.076065
# --------------------------------------------------
#   0%|          | 0/1327 [00:00<?, ?it/s]
# | epoch 10 |  iter 1 / 1327 | time 0[s] | perplexity 136.01
# | epoch 10 |  iter 21 / 1327 | time 4[s] | perplexity 81.29
# | epoch 10 |  iter 41 / 1327 | time 8[s] | perplexity 77.43
# | epoch 10 |  iter 61 / 1327 | time 12[s] | perplexity 77.22
# | epoch 10 |  iter 81 / 1327 | time 16[s] | perplexity 66.30
# | epoch 10 |  iter 101 / 1327 | time 20[s] | perplexity 63.92
# | epoch 10 |  iter 121 / 1327 | time 23[s] | perplexity 71.09
# | epoch 10 |  iter 141 / 1327 | time 28[s] | perplexity 75.00
# | epoch 10 |  iter 161 / 1327 | time 32[s] | perplexity 88.32
# | epoch 10 |  iter 181 / 1327 | time 35[s] | perplexity 94.69
# | epoch 10 |  iter 201 / 1327 | time 39[s] | perplexity 92.03
# | epoch 10 |  iter 221 / 1327 | time 44[s] | perplexity 88.07
# | epoch 10 |  iter 241 / 1327 | time 47[s] | perplexity 83.57
# | epoch 10 |  iter 261 / 1327 | time 51[s] | perplexity 89.14
# | epoch 10 |  iter 281 / 1327 | time 55[s] | perplexity 88.07
# | epoch 10 |  iter 301 / 1327 | time 59[s] | perplexity 72.78
# | epoch 10 |  iter 321 / 1327 | time 63[s] | perplexity 59.50
# | epoch 10 |  iter 341 / 1327 | time 67[s] | perplexity 84.81
# | epoch 10 |  iter 361 / 1327 | time 71[s] | perplexity 88.18
# | epoch 10 |  iter 381 / 1327 | time 75[s] | perplexity 74.15
# | epoch 10 |  iter 401 / 1327 | time 79[s] | perplexity 83.71
# | epoch 10 |  iter 421 / 1327 | time 83[s] | perplexity 71.93
# | epoch 10 |  iter 441 / 1327 | time 87[s] | perplexity 75.92
# | epoch 10 |  iter 461 / 1327 | time 91[s] | perplexity 76.46
# | epoch 10 |  iter 481 / 1327 | time 95[s] | perplexity 77.24
# | epoch 10 |  iter 501 / 1327 | time 98[s] | perplexity 83.78
# | epoch 10 |  iter 521 / 1327 | time 102[s] | perplexity 87.52
# | epoch 10 |  iter 541 / 1327 | time 106[s] | perplexity 88.82
# | epoch 10 |  iter 561 / 1327 | time 110[s] | perplexity 73.74
# | epoch 10 |  iter 581 / 1327 | time 114[s] | perplexity 69.71
# | epoch 10 |  iter 601 / 1327 | time 118[s] | perplexity 98.79
# | epoch 10 |  iter 621 / 1327 | time 122[s] | perplexity 91.25
# | epoch 10 |  iter 641 / 1327 | time 126[s] | perplexity 83.22
# | epoch 10 |  iter 661 / 1327 | time 130[s] | perplexity 76.43
# | epoch 10 |  iter 681 / 1327 | time 134[s] | perplexity 65.58
# | epoch 10 |  iter 701 / 1327 | time 137[s] | perplexity 79.30
# | epoch 10 |  iter 721 / 1327 | time 142[s] | perplexity 79.45
# | epoch 10 |  iter 741 / 1327 | time 146[s] | perplexity 70.18
# | epoch 10 |  iter 761 / 1327 | time 149[s] | perplexity 63.76
# | epoch 10 |  iter 781 / 1327 | time 154[s] | perplexity 69.54
# | epoch 10 |  iter 801 / 1327 | time 157[s] | perplexity 79.41
# | epoch 10 |  iter 821 / 1327 | time 161[s] | perplexity 80.30
# | epoch 10 |  iter 841 / 1327 | time 166[s] | perplexity 79.32
# | epoch 10 |  iter 861 / 1327 | time 169[s] | perplexity 77.57
# | epoch 10 |  iter 881 / 1327 | time 173[s] | perplexity 71.94
# | epoch 10 |  iter 901 / 1327 | time 177[s] | perplexity 90.97
# | epoch 10 |  iter 921 / 1327 | time 181[s] | perplexity 80.66
# | epoch 10 |  iter 941 / 1327 | time 185[s] | perplexity 85.51
# | epoch 10 |  iter 961 / 1327 | time 189[s] | perplexity 91.39
# | epoch 10 |  iter 981 / 1327 | time 194[s] | perplexity 88.07
# | epoch 10 |  iter 1001 / 1327 | time 198[s] | perplexity 75.00
# | epoch 10 |  iter 1021 / 1327 | time 202[s] | perplexity 88.62
# | epoch 10 |  iter 1041 / 1327 | time 206[s] | perplexity 75.81
# | epoch 10 |  iter 1061 / 1327 | time 210[s] | perplexity 72.68
# | epoch 10 |  iter 1081 / 1327 | time 214[s] | perplexity 59.36
# | epoch 10 |  iter 1101 / 1327 | time 218[s] | perplexity 60.26
# | epoch 10 |  iter 1121 / 1327 | time 222[s] | perplexity 82.38
# | epoch 10 |  iter 1141 / 1327 | time 226[s] | perplexity 80.34
# | epoch 10 |  iter 1161 / 1327 | time 230[s] | perplexity 67.22
# | epoch 10 |  iter 1181 / 1327 | time 234[s] | perplexity 75.65
# | epoch 10 |  iter 1201 / 1327 | time 238[s] | perplexity 62.46
# | epoch 10 |  iter 1221 / 1327 | time 242[s] | perplexity 62.69
# | epoch 10 |  iter 1241 / 1327 | time 246[s] | perplexity 75.62
# | epoch 10 |  iter 1261 / 1327 | time 250[s] | perplexity 71.16
# | epoch 10 |  iter 1281 / 1327 | time 254[s] | perplexity 70.37
# | epoch 10 |  iter 1301 / 1327 | time 258[s] | perplexity 89.09
# | epoch 10 |  iter 1321 / 1327 | time 262[s] | perplexity 87.46
# evaluating perplexity ...
# 209 / 210
# valid perplexity:  90.63078
# --------------------------------------------------
#   0%|          | 0/1327 [00:00<?, ?it/s]
# | epoch 11 |  iter 1 / 1327 | time 0[s] | perplexity 133.17
# | epoch 11 |  iter 21 / 1327 | time 4[s] | perplexity 77.69
# | epoch 11 |  iter 41 / 1327 | time 7[s] | perplexity 75.38
# | epoch 11 |  iter 61 / 1327 | time 12[s] | perplexity 73.73
# | epoch 11 |  iter 81 / 1327 | time 15[s] | perplexity 64.13
# | epoch 11 |  iter 101 / 1327 | time 19[s] | perplexity 61.40
# | epoch 11 |  iter 121 / 1327 | time 24[s] | perplexity 68.35
# | epoch 11 |  iter 141 / 1327 | time 27[s] | perplexity 72.42
# | epoch 11 |  iter 161 / 1327 | time 31[s] | perplexity 85.27
# | epoch 11 |  iter 181 / 1327 | time 35[s] | perplexity 90.22
# | epoch 11 |  iter 201 / 1327 | time 39[s] | perplexity 89.32
# | epoch 11 |  iter 221 / 1327 | time 43[s] | perplexity 85.45
# | epoch 11 |  iter 241 / 1327 | time 47[s] | perplexity 80.39
# | epoch 11 |  iter 261 / 1327 | time 51[s] | perplexity 86.63
# | epoch 11 |  iter 281 / 1327 | time 55[s] | perplexity 84.44
# | epoch 11 |  iter 301 / 1327 | time 58[s] | perplexity 70.41
# | epoch 11 |  iter 321 / 1327 | time 63[s] | perplexity 57.14
# | epoch 11 |  iter 341 / 1327 | time 66[s] | perplexity 82.00
# | epoch 11 |  iter 361 / 1327 | time 70[s] | perplexity 83.79
# | epoch 11 |  iter 381 / 1327 | time 75[s] | perplexity 70.81
# | epoch 11 |  iter 401 / 1327 | time 78[s] | perplexity 81.25
# | epoch 11 |  iter 421 / 1327 | time 82[s] | perplexity 68.17
# | epoch 11 |  iter 441 / 1327 | time 87[s] | perplexity 73.95
# | epoch 11 |  iter 461 / 1327 | time 90[s] | perplexity 73.60
# | epoch 11 |  iter 481 / 1327 | time 94[s] | perplexity 74.05
# | epoch 11 |  iter 501 / 1327 | time 98[s] | perplexity 81.12
# | epoch 11 |  iter 521 / 1327 | time 102[s] | perplexity 83.60
# | epoch 11 |  iter 541 / 1327 | time 106[s] | perplexity 84.84
# | epoch 11 |  iter 561 / 1327 | time 110[s] | perplexity 70.91
# | epoch 11 |  iter 581 / 1327 | time 114[s] | perplexity 65.59
# | epoch 11 |  iter 601 / 1327 | time 118[s] | perplexity 94.48
# | epoch 11 |  iter 621 / 1327 | time 122[s] | perplexity 87.42
# | epoch 11 |  iter 641 / 1327 | time 126[s] | perplexity 79.58
# | epoch 11 |  iter 661 / 1327 | time 130[s] | perplexity 73.08
# | epoch 11 |  iter 681 / 1327 | time 133[s] | perplexity 63.63
# | epoch 11 |  iter 701 / 1327 | time 138[s] | perplexity 76.48
# | epoch 11 |  iter 721 / 1327 | time 142[s] | perplexity 76.37
# | epoch 11 |  iter 741 / 1327 | time 145[s] | perplexity 67.64
# | epoch 11 |  iter 761 / 1327 | time 150[s] | perplexity 60.74
# | epoch 11 |  iter 781 / 1327 | time 153[s] | perplexity 67.11
# | epoch 11 |  iter 801 / 1327 | time 157[s] | perplexity 76.95
# | epoch 11 |  iter 821 / 1327 | time 161[s] | perplexity 76.71
# | epoch 11 |  iter 841 / 1327 | time 165[s] | perplexity 76.85
# | epoch 11 |  iter 861 / 1327 | time 169[s] | perplexity 75.65
# | epoch 11 |  iter 881 / 1327 | time 173[s] | perplexity 69.84
# | epoch 11 |  iter 901 / 1327 | time 177[s] | perplexity 88.22
# | epoch 11 |  iter 921 / 1327 | time 181[s] | perplexity 78.88
# | epoch 11 |  iter 941 / 1327 | time 185[s] | perplexity 83.72
# | epoch 11 |  iter 961 / 1327 | time 189[s] | perplexity 89.02
# | epoch 11 |  iter 981 / 1327 | time 192[s] | perplexity 84.95
# | epoch 11 |  iter 1001 / 1327 | time 196[s] | perplexity 72.97
# | epoch 11 |  iter 1021 / 1327 | time 201[s] | perplexity 85.85
# | epoch 11 |  iter 1041 / 1327 | time 204[s] | perplexity 73.20
# | epoch 11 |  iter 1061 / 1327 | time 208[s] | perplexity 70.47
# | epoch 11 |  iter 1081 / 1327 | time 212[s] | perplexity 57.57
# | epoch 11 |  iter 1101 / 1327 | time 216[s] | perplexity 59.06
# | epoch 11 |  iter 1121 / 1327 | time 220[s] | perplexity 80.90
# | epoch 11 |  iter 1141 / 1327 | time 224[s] | perplexity 78.48
# | epoch 11 |  iter 1161 / 1327 | time 228[s] | perplexity 64.96
# | epoch 11 |  iter 1181 / 1327 | time 232[s] | perplexity 72.47
# | epoch 11 |  iter 1201 / 1327 | time 236[s] | perplexity 60.99
# | epoch 11 |  iter 1221 / 1327 | time 240[s] | perplexity 60.07
# | epoch 11 |  iter 1241 / 1327 | time 244[s] | perplexity 72.88
# | epoch 11 |  iter 1261 / 1327 | time 248[s] | perplexity 69.20
# | epoch 11 |  iter 1281 / 1327 | time 252[s] | perplexity 69.19
# | epoch 11 |  iter 1301 / 1327 | time 255[s] | perplexity 86.37
# | epoch 11 |  iter 1321 / 1327 | time 260[s] | perplexity 84.40
# evaluating perplexity ...
# 209 / 210
# valid perplexity:  90.1163
# --------------------------------------------------
#   0%|          | 0/1327 [00:00<?, ?it/s]
# | epoch 12 |  iter 1 / 1327 | time 0[s] | perplexity 126.63
# | epoch 12 |  iter 21 / 1327 | time 3[s] | perplexity 76.54
# | epoch 12 |  iter 41 / 1327 | time 8[s] | perplexity 72.66
# ...
# | epoch 37 |  iter 461 / 1327 | time 92[s] | perplexity 43.62
# | epoch 37 |  iter 481 / 1327 | time 96[s] | perplexity 44.01
# | epoch 37 |  iter 501 / 1327 | time 100[s] | perplexity 48.11
# | epoch 37 |  iter 521 / 1327 | time 104[s] | perplexity 49.77
# | epoch 37 |  iter 541 / 1327 | time 108[s] | perplexity 50.19
# | epoch 37 |  iter 561 / 1327 | time 112[s] | perplexity 42.96
# | epoch 37 |  iter 581 / 1327 | time 116[s] | perplexity 39.15
# | epoch 37 |  iter 601 / 1327 | time 120[s] | perplexity 56.56
# | epoch 37 |  iter 621 / 1327 | time 125[s] | perplexity 51.01
# | epoch 37 |  iter 641 / 1327 | time 128[s] | perplexity 47.52
# | epoch 37 |  iter 661 / 1327 | time 132[s] | perplexity 43.27
# | epoch 37 |  iter 681 / 1327 | time 137[s] | perplexity 38.05
# | epoch 37 |  iter 701 / 1327 | time 141[s] | perplexity 45.13
# | epoch 37 |  iter 721 / 1327 | time 144[s] | perplexity 44.74
# | epoch 37 |  iter 741 / 1327 | time 149[s] | perplexity 40.32
# | epoch 37 |  iter 761 / 1327 | time 153[s] | perplexity 36.07
# | epoch 37 |  iter 781 / 1327 | time 156[s] | perplexity 39.38
# | epoch 37 |  iter 801 / 1327 | time 160[s] | perplexity 45.28
# | epoch 37 |  iter 821 / 1327 | time 165[s] | perplexity 45.63
# | epoch 37 |  iter 841 / 1327 | time 169[s] | perplexity 44.03
# | epoch 37 |  iter 861 / 1327 | time 172[s] | perplexity 44.10
# | epoch 37 |  iter 881 / 1327 | time 177[s] | perplexity 40.23
# | epoch 37 |  iter 901 / 1327 | time 181[s] | perplexity 51.53
# | epoch 37 |  iter 921 / 1327 | time 185[s] | perplexity 46.10
# | epoch 37 |  iter 941 / 1327 | time 189[s] | perplexity 49.23
# | epoch 37 |  iter 961 / 1327 | time 193[s] | perplexity 51.28
# | epoch 37 |  iter 981 / 1327 | time 196[s] | perplexity 49.45
# | epoch 37 |  iter 1001 / 1327 | time 201[s] | perplexity 42.36
# | epoch 37 |  iter 1021 / 1327 | time 205[s] | perplexity 49.30
# | epoch 37 |  iter 1041 / 1327 | time 208[s] | perplexity 42.89
# | epoch 37 |  iter 1061 / 1327 | time 213[s] | perplexity 39.85
# | epoch 37 |  iter 1081 / 1327 | time 216[s] | perplexity 33.79
# | epoch 37 |  iter 1101 / 1327 | time 220[s] | perplexity 33.90
# | epoch 37 |  iter 1121 / 1327 | time 225[s] | perplexity 45.85
# | epoch 37 |  iter 1141 / 1327 | time 228[s] | perplexity 44.22
# | epoch 37 |  iter 1161 / 1327 | time 232[s] | perplexity 37.15
# | epoch 37 |  iter 1181 / 1327 | time 237[s] | perplexity 41.72
# | epoch 37 |  iter 1201 / 1327 | time 240[s] | perplexity 33.94
# | epoch 37 |  iter 1221 / 1327 | time 244[s] | perplexity 34.36
# | epoch 37 |  iter 1241 / 1327 | time 248[s] | perplexity 41.20
# | epoch 37 |  iter 1261 / 1327 | time 252[s] | perplexity 39.53
# | epoch 37 |  iter 1281 / 1327 | time 256[s] | perplexity 39.22
# | epoch 37 |  iter 1301 / 1327 | time 260[s] | perplexity 48.40
# | epoch 37 |  iter 1321 / 1327 | time 264[s] | perplexity 48.04
# evaluating perplexity ...
# 209 / 210
# valid perplexity:  79.93812
# --------------------------------------------------
#   0%|          | 0/1327 [00:00<?, ?it/s]
# | epoch 38 |  iter 1 / 1327 | time 0[s] | perplexity 76.28
# | epoch 38 |  iter 21 / 1327 | time 4[s] | perplexity 47.69
# | epoch 38 |  iter 41 / 1327 | time 8[s] | perplexity 46.55
# | epoch 38 |  iter 61 / 1327 | time 12[s] | perplexity 45.16
# | epoch 38 |  iter 81 / 1327 | time 16[s] | perplexity 38.88
# | epoch 38 |  iter 101 / 1327 | time 20[s] | perplexity 38.47
# | epoch 38 |  iter 121 / 1327 | time 24[s] | perplexity 42.53
# | epoch 38 |  iter 141 / 1327 | time 27[s] | perplexity 43.90
# | epoch 38 |  iter 161 / 1327 | time 32[s] | perplexity 51.52
# | epoch 38 |  iter 181 / 1327 | time 36[s] | perplexity 54.35
# | epoch 38 |  iter 201 / 1327 | time 39[s] | perplexity 55.24
# | epoch 38 |  iter 221 / 1327 | time 44[s] | perplexity 51.95
# | epoch 38 |  iter 241 / 1327 | time 48[s] | perplexity 48.47
# | epoch 38 |  iter 261 / 1327 | time 52[s] | perplexity 52.35
# | epoch 38 |  iter 281 / 1327 | time 56[s] | perplexity 51.24
# | epoch 38 |  iter 301 / 1327 | time 60[s] | perplexity 41.97
# | epoch 38 |  iter 321 / 1327 | time 64[s] | perplexity 34.68
# | epoch 38 |  iter 341 / 1327 | time 68[s] | perplexity 48.74
# | epoch 38 |  iter 361 / 1327 | time 72[s] | perplexity 49.88
# | epoch 38 |  iter 381 / 1327 | time 76[s] | perplexity 43.30
# | epoch 38 |  iter 401 / 1327 | time 80[s] | perplexity 49.13
# | epoch 38 |  iter 421 / 1327 | time 84[s] | perplexity 41.37
# | epoch 38 |  iter 441 / 1327 | time 88[s] | perplexity 42.88
# | epoch 38 |  iter 461 / 1327 | time 92[s] | perplexity 43.30
# | epoch 38 |  iter 481 / 1327 | time 96[s] | perplexity 44.42
# | epoch 38 |  iter 501 / 1327 | time 100[s] | perplexity 48.08
# | epoch 38 |  iter 521 / 1327 | time 104[s] | perplexity 49.48
# | epoch 38 |  iter 541 / 1327 | time 108[s] | perplexity 50.95
# | epoch 38 |  iter 561 / 1327 | time 112[s] | perplexity 42.43
# | epoch 38 |  iter 581 / 1327 | time 116[s] | perplexity 39.23
# | epoch 38 |  iter 601 / 1327 | time 120[s] | perplexity 56.05
# | epoch 38 |  iter 621 / 1327 | time 124[s] | perplexity 50.84
# | epoch 38 |  iter 641 / 1327 | time 128[s] | perplexity 47.33
# | epoch 38 |  iter 661 / 1327 | time 132[s] | perplexity 43.43
# | epoch 38 |  iter 681 / 1327 | time 136[s] | perplexity 38.64
# | epoch 38 |  iter 701 / 1327 | time 140[s] | perplexity 45.24
# | epoch 38 |  iter 721 / 1327 | time 144[s] | perplexity 45.51
# | epoch 38 |  iter 741 / 1327 | time 148[s] | perplexity 40.49
# | epoch 38 |  iter 761 / 1327 | time 152[s] | perplexity 36.57
# | epoch 38 |  iter 781 / 1327 | time 156[s] | perplexity 39.48
# | epoch 38 |  iter 801 / 1327 | time 160[s] | perplexity 44.08
# | epoch 38 |  iter 821 / 1327 | time 164[s] | perplexity 45.60
# | epoch 38 |  iter 841 / 1327 | time 169[s] | perplexity 44.12
# | epoch 38 |  iter 861 / 1327 | time 172[s] | perplexity 43.42
# | epoch 38 |  iter 881 / 1327 | time 176[s] | perplexity 41.03
# | epoch 38 |  iter 901 / 1327 | time 181[s] | perplexity 51.72
# | epoch 38 |  iter 921 / 1327 | time 185[s] | perplexity 46.17
# | epoch 38 |  iter 941 / 1327 | time 188[s] | perplexity 49.68
# | epoch 38 |  iter 961 / 1327 | time 193[s] | perplexity 51.95
# | epoch 38 |  iter 981 / 1327 | time 197[s] | perplexity 49.17
# | epoch 38 |  iter 1001 / 1327 | time 201[s] | perplexity 41.72
# | epoch 38 |  iter 1021 / 1327 | time 205[s] | perplexity 48.77
# | epoch 38 |  iter 1041 / 1327 | time 209[s] | perplexity 42.60
# | epoch 38 |  iter 1061 / 1327 | time 213[s] | perplexity 40.26
# | epoch 38 |  iter 1081 / 1327 | time 217[s] | perplexity 33.45
# | epoch 38 |  iter 1101 / 1327 | time 221[s] | perplexity 33.73
# | epoch 38 |  iter 1121 / 1327 | time 225[s] | perplexity 45.75
# | epoch 38 |  iter 1141 / 1327 | time 229[s] | perplexity 44.89
# | epoch 38 |  iter 1161 / 1327 | time 233[s] | perplexity 37.35
# | epoch 38 |  iter 1181 / 1327 | time 237[s] | perplexity 41.40
# | epoch 38 |  iter 1201 / 1327 | time 241[s] | perplexity 34.16
# | epoch 38 |  iter 1221 / 1327 | time 245[s] | perplexity 34.57
# | epoch 38 |  iter 1241 / 1327 | time 249[s] | perplexity 40.56
# | epoch 38 |  iter 1261 / 1327 | time 253[s] | perplexity 39.11
# | epoch 38 |  iter 1281 / 1327 | time 257[s] | perplexity 39.55
# | epoch 38 |  iter 1301 / 1327 | time 261[s] | perplexity 48.29
# | epoch 38 |  iter 1321 / 1327 | time 265[s] | perplexity 48.17
# evaluating perplexity ...
# 209 / 210
# valid perplexity:  79.937996
# --------------------------------------------------
#   0%|          | 0/1327 [00:00<?, ?it/s]
# | epoch 39 |  iter 1 / 1327 | time 0[s] | perplexity 73.60
# | epoch 39 |  iter 21 / 1327 | time 4[s] | perplexity 48.13
# | epoch 39 |  iter 41 / 1327 | time 8[s] | perplexity 46.99
# | epoch 39 |  iter 61 / 1327 | time 12[s] | perplexity 44.53
# | epoch 39 |  iter 81 / 1327 | time 16[s] | perplexity 38.95
# | epoch 39 |  iter 101 / 1327 | time 19[s] | perplexity 38.70
# | epoch 39 |  iter 121 / 1327 | time 24[s] | perplexity 42.43
# | epoch 39 |  iter 141 / 1327 | time 28[s] | perplexity 43.57
# | epoch 39 |  iter 161 / 1327 | time 32[s] | perplexity 51.72
# | epoch 39 |  iter 181 / 1327 | time 36[s] | perplexity 54.64
# | epoch 39 |  iter 201 / 1327 | time 40[s] | perplexity 54.73
# | epoch 39 |  iter 221 / 1327 | time 44[s] | perplexity 52.53
# | epoch 39 |  iter 241 / 1327 | time 48[s] | perplexity 48.40
# | epoch 39 |  iter 261 / 1327 | time 52[s] | perplexity 52.42
# | epoch 39 |  iter 281 / 1327 | time 56[s] | perplexity 51.21
# | epoch 39 |  iter 301 / 1327 | time 60[s] | perplexity 41.28
# | epoch 39 |  iter 321 / 1327 | time 64[s] | perplexity 34.20
# | epoch 39 |  iter 341 / 1327 | time 68[s] | perplexity 48.45
# | epoch 39 |  iter 361 / 1327 | time 72[s] | perplexity 49.13
# | epoch 39 |  iter 381 / 1327 | time 76[s] | perplexity 42.70
# | epoch 39 |  iter 401 / 1327 | time 80[s] | perplexity 48.08
# | epoch 39 |  iter 421 / 1327 | time 84[s] | perplexity 40.76
# | epoch 39 |  iter 441 / 1327 | time 88[s] | perplexity 43.16
# | epoch 39 |  iter 461 / 1327 | time 92[s] | perplexity 43.86
# | epoch 39 |  iter 481 / 1327 | time 96[s] | perplexity 44.07
# | epoch 39 |  iter 501 / 1327 | time 101[s] | perplexity 48.09
# | epoch 39 |  iter 521 / 1327 | time 104[s] | perplexity 48.78
# | epoch 39 |  iter 541 / 1327 | time 109[s] | perplexity 50.40
# | epoch 39 |  iter 561 / 1327 | time 113[s] | perplexity 42.98
# | epoch 39 |  iter 581 / 1327 | time 117[s] | perplexity 38.82
# | epoch 39 |  iter 601 / 1327 | time 121[s] | perplexity 56.41
# | epoch 39 |  iter 621 / 1327 | time 125[s] | perplexity 51.57
# | epoch 39 |  iter 641 / 1327 | time 129[s] | perplexity 46.94
# | epoch 39 |  iter 661 / 1327 | time 133[s] | perplexity 43.85
# | epoch 39 |  iter 681 / 1327 | time 137[s] | perplexity 38.41
# | epoch 39 |  iter 701 / 1327 | time 141[s] | perplexity 44.42
# | epoch 39 |  iter 721 / 1327 | time 145[s] | perplexity 44.56
# | epoch 39 |  iter 741 / 1327 | time 149[s] | perplexity 40.54
# | epoch 39 |  iter 761 / 1327 | time 153[s] | perplexity 36.20
# | epoch 39 |  iter 781 / 1327 | time 157[s] | perplexity 39.10
# | epoch 39 |  iter 801 / 1327 | time 161[s] | perplexity 44.58
# | epoch 39 |  iter 821 / 1327 | time 165[s] | perplexity 45.40
# | epoch 39 |  iter 841 / 1327 | time 169[s] | perplexity 44.68
# | epoch 39 |  iter 861 / 1327 | time 174[s] | perplexity 44.25
# | epoch 39 |  iter 881 / 1327 | time 177[s] | perplexity 41.05
# | epoch 39 |  iter 901 / 1327 | time 181[s] | perplexity 52.06
# | epoch 39 |  iter 921 / 1327 | time 186[s] | perplexity 46.04
# | epoch 39 |  iter 941 / 1327 | time 190[s] | perplexity 48.86
# | epoch 39 |  iter 961 / 1327 | time 193[s] | perplexity 51.45
# | epoch 39 |  iter 981 / 1327 | time 198[s] | perplexity 48.64
# | epoch 39 |  iter 1001 / 1327 | time 202[s] | perplexity 41.81
# | epoch 39 |  iter 1021 / 1327 | time 205[s] | perplexity 48.92
# | epoch 39 |  iter 1041 / 1327 | time 209[s] | perplexity 42.62
# | epoch 39 |  iter 1061 / 1327 | time 214[s] | perplexity 40.49
# | epoch 39 |  iter 1081 / 1327 | time 217[s] | perplexity 33.46
# | epoch 39 |  iter 1101 / 1327 | time 222[s] | perplexity 33.87
# | epoch 39 |  iter 1121 / 1327 | time 226[s] | perplexity 45.70
# | epoch 39 |  iter 1141 / 1327 | time 230[s] | perplexity 43.66
# | epoch 39 |  iter 1161 / 1327 | time 233[s] | perplexity 37.01
# | epoch 39 |  iter 1181 / 1327 | time 238[s] | perplexity 41.31
# | epoch 39 |  iter 1201 / 1327 | time 242[s] | perplexity 34.46
# | epoch 39 |  iter 1221 / 1327 | time 245[s] | perplexity 34.37
# | epoch 39 |  iter 1241 / 1327 | time 250[s] | perplexity 41.36
# | epoch 39 |  iter 1261 / 1327 | time 254[s] | perplexity 39.56
# | epoch 39 |  iter 1281 / 1327 | time 258[s] | perplexity 39.25
# | epoch 39 |  iter 1301 / 1327 | time 262[s] | perplexity 48.21
# | epoch 39 |  iter 1321 / 1327 | time 266[s] | perplexity 48.42
# evaluating perplexity ...
# 209 / 210
# valid perplexity:  79.93651
# --------------------------------------------------
#   0%|          | 0/1327 [00:00<?, ?it/s]
# | epoch 40 |  iter 1 / 1327 | time 0[s] | perplexity 78.07
# | epoch 40 |  iter 21 / 1327 | time 4[s] | perplexity 48.24
# | epoch 40 |  iter 41 / 1327 | time 8[s] | perplexity 46.57
# | epoch 40 |  iter 61 / 1327 | time 12[s] | perplexity 44.58
# | epoch 40 |  iter 81 / 1327 | time 16[s] | perplexity 39.30
# | epoch 40 |  iter 101 / 1327 | time 20[s] | perplexity 38.32
# | epoch 40 |  iter 121 / 1327 | time 24[s] | perplexity 41.53
# | epoch 40 |  iter 141 / 1327 | time 28[s] | perplexity 43.73
# | epoch 40 |  iter 161 / 1327 | time 32[s] | perplexity 52.00
# | epoch 40 |  iter 181 / 1327 | time 36[s] | perplexity 54.10
# | epoch 40 |  iter 201 / 1327 | time 40[s] | perplexity 54.56
# | epoch 40 |  iter 221 / 1327 | time 44[s] | perplexity 53.16
# | epoch 40 |  iter 241 / 1327 | time 48[s] | perplexity 48.47
# | epoch 40 |  iter 261 / 1327 | time 52[s] | perplexity 53.26
# | epoch 40 |  iter 281 / 1327 | time 56[s] | perplexity 50.70
# | epoch 40 |  iter 301 / 1327 | time 60[s] | perplexity 41.38
# | epoch 40 |  iter 321 / 1327 | time 64[s] | perplexity 34.89
# | epoch 40 |  iter 341 / 1327 | time 68[s] | perplexity 48.35
# | epoch 40 |  iter 361 / 1327 | time 72[s] | perplexity 49.64
# | epoch 40 |  iter 381 / 1327 | time 76[s] | perplexity 42.51
# | epoch 40 |  iter 401 / 1327 | time 80[s] | perplexity 48.18
# | epoch 40 |  iter 421 / 1327 | time 84[s] | perplexity 40.94
# | epoch 40 |  iter 441 / 1327 | time 88[s] | perplexity 42.55
# | epoch 40 |  iter 461 / 1327 | time 92[s] | perplexity 43.21
# | epoch 40 |  iter 481 / 1327 | time 96[s] | perplexity 43.63
# | epoch 40 |  iter 501 / 1327 | time 100[s] | perplexity 48.34
# | epoch 40 |  iter 521 / 1327 | time 105[s] | perplexity 49.69
# | epoch 40 |  iter 541 / 1327 | time 108[s] | perplexity 50.79
# | epoch 40 |  iter 561 / 1327 | time 112[s] | perplexity 41.98
# | epoch 40 |  iter 581 / 1327 | time 117[s] | perplexity 39.20
# | epoch 40 |  iter 601 / 1327 | time 121[s] | perplexity 57.35
# | epoch 40 |  iter 621 / 1327 | time 124[s] | perplexity 51.48
# | epoch 40 |  iter 641 / 1327 | time 129[s] | perplexity 47.19
# | epoch 40 |  iter 661 / 1327 | time 133[s] | perplexity 43.20
# | epoch 40 |  iter 681 / 1327 | time 137[s] | perplexity 38.11
# | epoch 40 |  iter 701 / 1327 | time 141[s] | perplexity 44.98
# | epoch 40 |  iter 721 / 1327 | time 145[s] | perplexity 45.52
# | epoch 40 |  iter 741 / 1327 | time 149[s] | perplexity 40.27
# | epoch 40 |  iter 761 / 1327 | time 153[s] | perplexity 35.90
# | epoch 40 |  iter 781 / 1327 | time 157[s] | perplexity 39.27
# | epoch 40 |  iter 801 / 1327 | time 161[s] | perplexity 44.24
# | epoch 40 |  iter 821 / 1327 | time 165[s] | perplexity 45.32
# | epoch 40 |  iter 841 / 1327 | time 169[s] | perplexity 44.13
# | epoch 40 |  iter 861 / 1327 | time 173[s] | perplexity 44.09
# | epoch 40 |  iter 881 / 1327 | time 177[s] | perplexity 40.84
# | epoch 40 |  iter 901 / 1327 | time 181[s] | perplexity 51.54
# | epoch 40 |  iter 921 / 1327 | time 185[s] | perplexity 46.59
# | epoch 40 |  iter 941 / 1327 | time 189[s] | perplexity 49.89
# | epoch 40 |  iter 961 / 1327 | time 193[s] | perplexity 51.36
# | epoch 40 |  iter 981 / 1327 | time 197[s] | perplexity 48.63
# | epoch 40 |  iter 1001 / 1327 | time 201[s] | perplexity 42.28
# | epoch 40 |  iter 1021 / 1327 | time 205[s] | perplexity 48.89
# | epoch 40 |  iter 1041 / 1327 | time 209[s] | perplexity 41.94
# | epoch 40 |  iter 1061 / 1327 | time 213[s] | perplexity 40.19
# | epoch 40 |  iter 1081 / 1327 | time 217[s] | perplexity 33.65
# | epoch 40 |  iter 1101 / 1327 | time 221[s] | perplexity 33.87
# | epoch 40 |  iter 1121 / 1327 | time 225[s] | perplexity 46.02
# | epoch 40 |  iter 1141 / 1327 | time 230[s] | perplexity 44.43
# | epoch 40 |  iter 1161 / 1327 | time 233[s] | perplexity 36.80
# | epoch 40 |  iter 1181 / 1327 | time 237[s] | perplexity 41.27
# | epoch 40 |  iter 1201 / 1327 | time 242[s] | perplexity 34.33
# | epoch 40 |  iter 1221 / 1327 | time 245[s] | perplexity 34.28
# | epoch 40 |  iter 1241 / 1327 | time 249[s] | perplexity 41.43
# | epoch 40 |  iter 1261 / 1327 | time 254[s] | perplexity 39.27
# | epoch 40 |  iter 1281 / 1327 | time 257[s] | perplexity 39.96
# | epoch 40 |  iter 1301 / 1327 | time 261[s] | perplexity 49.43
# | epoch 40 |  iter 1321 / 1327 | time 266[s] | perplexity 48.23
# evaluating perplexity ...
# 209 / 210
# valid perplexity:  79.932434
# --------------------------------------------------

# %%
# 基于验证数据进行评价
model.reset_state()
ppl_test = eval_perplexity(model, corpus_test)
print('test perplexity: ', ppl_test)
# Out:
# evaluating perplexity ...
# 234 / 235
# test perplexity:  76.23469

# %% [markdown]
# CPU需要两天，GPUTesla运行了3个小时……

# %%
import torch
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'
