# %%
import os
import sys

sys.path.append(os.pardir)  # 为了导入父目录的文件而进行的设定
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.multi_layer_net import MultiLayerNet
from common.optimizer import SGD

# %%
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# %%
x_train = x_train[:300]
t_train = t_train[:300]
weight_decay_lambda = 0.1

# %%
network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100], output_size=10,
                        weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01)

# %%
max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

# %%
for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]

    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)

    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)

        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))

        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break
# Out:
# epoch:0, train acc:0.11333333333333333, test acc:0.1178
# epoch:1, train acc:0.12666666666666668, test acc:0.1217
# epoch:2, train acc:0.13333333333333333, test acc:0.1319
# epoch:3, train acc:0.18666666666666668, test acc:0.1604
# epoch:4, train acc:0.25333333333333335, test acc:0.1846
# epoch:5, train acc:0.31333333333333335, test acc:0.2238
# epoch:6, train acc:0.3466666666666667, test acc:0.2568
# epoch:7, train acc:0.38, test acc:0.277
# epoch:8, train acc:0.37333333333333335, test acc:0.2955
# epoch:9, train acc:0.42, test acc:0.3211
# epoch:10, train acc:0.43666666666666665, test acc:0.3433
# epoch:11, train acc:0.45, test acc:0.3572
# epoch:12, train acc:0.44, test acc:0.366
# epoch:13, train acc:0.47, test acc:0.3719
# epoch:14, train acc:0.47, test acc:0.3808
# epoch:15, train acc:0.49, test acc:0.4001
# epoch:16, train acc:0.5266666666666666, test acc:0.4296
# epoch:17, train acc:0.5433333333333333, test acc:0.4323
# epoch:18, train acc:0.57, test acc:0.4587
# epoch:19, train acc:0.5933333333333334, test acc:0.4734
# epoch:20, train acc:0.5833333333333334, test acc:0.474
# epoch:21, train acc:0.6, test acc:0.4867
# epoch:22, train acc:0.6266666666666667, test acc:0.5021
# epoch:23, train acc:0.6466666666666666, test acc:0.5249
# epoch:24, train acc:0.6566666666666666, test acc:0.5287
# epoch:25, train acc:0.68, test acc:0.5384
# epoch:26, train acc:0.6766666666666666, test acc:0.5522
# epoch:27, train acc:0.6933333333333334, test acc:0.5628
# epoch:28, train acc:0.7066666666666667, test acc:0.573
# epoch:29, train acc:0.7133333333333334, test acc:0.5792
# epoch:30, train acc:0.7066666666666667, test acc:0.5737
# epoch:31, train acc:0.7233333333333334, test acc:0.5957
# epoch:32, train acc:0.7333333333333333, test acc:0.5976
# epoch:33, train acc:0.7533333333333333, test acc:0.6112
# epoch:34, train acc:0.7233333333333334, test acc:0.5905
# epoch:35, train acc:0.7533333333333333, test acc:0.6012
# epoch:36, train acc:0.79, test acc:0.6182
# epoch:37, train acc:0.7933333333333333, test acc:0.627
# epoch:38, train acc:0.81, test acc:0.6312
# epoch:39, train acc:0.7966666666666666, test acc:0.6316
# epoch:40, train acc:0.81, test acc:0.6473
# epoch:41, train acc:0.79, test acc:0.6348
# epoch:42, train acc:0.8133333333333334, test acc:0.6542
# epoch:43, train acc:0.8233333333333334, test acc:0.6543
# epoch:44, train acc:0.78, test acc:0.6329
# epoch:45, train acc:0.8233333333333334, test acc:0.6683
# epoch:46, train acc:0.83, test acc:0.6692
# epoch:47, train acc:0.8533333333333334, test acc:0.6811
# epoch:48, train acc:0.8433333333333334, test acc:0.6862
# epoch:49, train acc:0.8666666666666667, test acc:0.6828
# epoch:50, train acc:0.8333333333333334, test acc:0.674
# epoch:51, train acc:0.8333333333333334, test acc:0.6756
# epoch:52, train acc:0.8566666666666667, test acc:0.6851
# epoch:53, train acc:0.87, test acc:0.6935
# epoch:54, train acc:0.8633333333333333, test acc:0.7021
# epoch:55, train acc:0.86, test acc:0.7009
# epoch:56, train acc:0.8766666666666667, test acc:0.709
# epoch:57, train acc:0.8666666666666667, test acc:0.6871
# epoch:58, train acc:0.88, test acc:0.7094
# epoch:59, train acc:0.89, test acc:0.7075
# epoch:60, train acc:0.8633333333333333, test acc:0.7021
# epoch:61, train acc:0.87, test acc:0.7019
# epoch:62, train acc:0.8866666666666667, test acc:0.7169
# epoch:63, train acc:0.8733333333333333, test acc:0.7117
# epoch:64, train acc:0.87, test acc:0.709
# epoch:65, train acc:0.87, test acc:0.716
# epoch:66, train acc:0.8733333333333333, test acc:0.7152
# epoch:67, train acc:0.8933333333333333, test acc:0.7167
# epoch:68, train acc:0.8866666666666667, test acc:0.7172
# epoch:69, train acc:0.8966666666666666, test acc:0.7159
# epoch:70, train acc:0.89, test acc:0.7153
# epoch:71, train acc:0.9033333333333333, test acc:0.72
# epoch:72, train acc:0.91, test acc:0.7217
# epoch:73, train acc:0.8733333333333333, test acc:0.7247
# epoch:74, train acc:0.9033333333333333, test acc:0.7278
# epoch:75, train acc:0.9, test acc:0.7277
# epoch:76, train acc:0.8766666666666667, test acc:0.722
# epoch:77, train acc:0.89, test acc:0.7243
# epoch:78, train acc:0.8933333333333333, test acc:0.7267
# epoch:79, train acc:0.88, test acc:0.7168
# epoch:80, train acc:0.8933333333333333, test acc:0.7229
# epoch:81, train acc:0.9066666666666666, test acc:0.7276
# epoch:82, train acc:0.8966666666666666, test acc:0.7311
# epoch:83, train acc:0.8966666666666666, test acc:0.7275
# epoch:84, train acc:0.8933333333333333, test acc:0.7288
# epoch:85, train acc:0.9066666666666666, test acc:0.7175
# epoch:86, train acc:0.91, test acc:0.733
# epoch:87, train acc:0.91, test acc:0.737
# epoch:88, train acc:0.9166666666666666, test acc:0.7338
# epoch:89, train acc:0.9066666666666666, test acc:0.7325
# epoch:90, train acc:0.9, test acc:0.7298
# epoch:91, train acc:0.8933333333333333, test acc:0.7334
# epoch:92, train acc:0.9, test acc:0.7287
# epoch:93, train acc:0.91, test acc:0.7368
# epoch:94, train acc:0.9133333333333333, test acc:0.738
# epoch:95, train acc:0.9166666666666666, test acc:0.7271
# epoch:96, train acc:0.9233333333333333, test acc:0.7414
# epoch:97, train acc:0.9233333333333333, test acc:0.741
# epoch:98, train acc:0.9033333333333333, test acc:0.7399
# epoch:99, train acc:0.9166666666666666, test acc:0.7375
# epoch:100, train acc:0.91, test acc:0.7345
# epoch:101, train acc:0.9233333333333333, test acc:0.7427
# epoch:102, train acc:0.92, test acc:0.7409
# epoch:103, train acc:0.9233333333333333, test acc:0.7427
# epoch:104, train acc:0.91, test acc:0.7414
# epoch:105, train acc:0.9233333333333333, test acc:0.7289
# epoch:106, train acc:0.9133333333333333, test acc:0.7329
# epoch:107, train acc:0.92, test acc:0.7364
# epoch:108, train acc:0.9166666666666666, test acc:0.7381
# epoch:109, train acc:0.91, test acc:0.738
# epoch:110, train acc:0.91, test acc:0.7457
# epoch:111, train acc:0.9233333333333333, test acc:0.7455
# epoch:112, train acc:0.91, test acc:0.729
# epoch:113, train acc:0.9, test acc:0.7401
# epoch:114, train acc:0.91, test acc:0.7428
# epoch:115, train acc:0.91, test acc:0.7441
# epoch:116, train acc:0.9266666666666666, test acc:0.7484
# epoch:117, train acc:0.92, test acc:0.7476
# epoch:118, train acc:0.9166666666666666, test acc:0.748
# epoch:119, train acc:0.9133333333333333, test acc:0.745
# epoch:120, train acc:0.9233333333333333, test acc:0.7429
# epoch:121, train acc:0.92, test acc:0.7412
# epoch:122, train acc:0.9066666666666666, test acc:0.7319
# epoch:123, train acc:0.9033333333333333, test acc:0.7361
# epoch:124, train acc:0.8966666666666666, test acc:0.7313
# epoch:125, train acc:0.9166666666666666, test acc:0.7409
# epoch:126, train acc:0.91, test acc:0.7398
# epoch:127, train acc:0.93, test acc:0.7447
# epoch:128, train acc:0.9033333333333333, test acc:0.7365
# epoch:129, train acc:0.9166666666666666, test acc:0.7461
# epoch:130, train acc:0.9133333333333333, test acc:0.7339
# epoch:131, train acc:0.9133333333333333, test acc:0.7391
# epoch:132, train acc:0.9233333333333333, test acc:0.7404
# epoch:133, train acc:0.9066666666666666, test acc:0.7229
# epoch:134, train acc:0.92, test acc:0.7351
# epoch:135, train acc:0.91, test acc:0.7368
# epoch:136, train acc:0.9266666666666666, test acc:0.7456
# epoch:137, train acc:0.9233333333333333, test acc:0.7517
# epoch:138, train acc:0.9233333333333333, test acc:0.7414
# epoch:139, train acc:0.9166666666666666, test acc:0.7436
# epoch:140, train acc:0.9166666666666666, test acc:0.7429
# epoch:141, train acc:0.9333333333333333, test acc:0.751
# epoch:142, train acc:0.9166666666666666, test acc:0.7479
# epoch:143, train acc:0.9233333333333333, test acc:0.7477
# epoch:144, train acc:0.9266666666666666, test acc:0.7444
# epoch:145, train acc:0.9233333333333333, test acc:0.7445
# epoch:146, train acc:0.93, test acc:0.7489
# epoch:147, train acc:0.9266666666666666, test acc:0.7521
# epoch:148, train acc:0.92, test acc:0.7454
# epoch:149, train acc:0.9233333333333333, test acc:0.7448
# epoch:150, train acc:0.9133333333333333, test acc:0.7409
# epoch:151, train acc:0.92, test acc:0.7374
# epoch:152, train acc:0.9166666666666666, test acc:0.7432
# epoch:153, train acc:0.92, test acc:0.7446
# epoch:154, train acc:0.92, test acc:0.7378
# epoch:155, train acc:0.93, test acc:0.743
# epoch:156, train acc:0.92, test acc:0.7421
# epoch:157, train acc:0.92, test acc:0.7472
# epoch:158, train acc:0.9233333333333333, test acc:0.7476
# epoch:159, train acc:0.92, test acc:0.7445
# epoch:160, train acc:0.9366666666666666, test acc:0.7514
# epoch:161, train acc:0.9333333333333333, test acc:0.7488
# epoch:162, train acc:0.9333333333333333, test acc:0.7554
# epoch:163, train acc:0.9266666666666666, test acc:0.7499
# epoch:164, train acc:0.9266666666666666, test acc:0.748
# epoch:165, train acc:0.9133333333333333, test acc:0.7466
# epoch:166, train acc:0.92, test acc:0.7471
# epoch:167, train acc:0.91, test acc:0.7466
# epoch:168, train acc:0.9266666666666666, test acc:0.7486
# epoch:169, train acc:0.9066666666666666, test acc:0.7416
# epoch:170, train acc:0.9166666666666666, test acc:0.7409
# epoch:171, train acc:0.92, test acc:0.7424
# epoch:172, train acc:0.9133333333333333, test acc:0.732
# epoch:173, train acc:0.92, test acc:0.7499
# epoch:174, train acc:0.92, test acc:0.749
# epoch:175, train acc:0.91, test acc:0.7435
# epoch:176, train acc:0.91, test acc:0.7394
# epoch:177, train acc:0.91, test acc:0.7415
# epoch:178, train acc:0.9233333333333333, test acc:0.7442
# epoch:179, train acc:0.91, test acc:0.7379
# epoch:180, train acc:0.9133333333333333, test acc:0.7314
# epoch:181, train acc:0.92, test acc:0.739
# epoch:182, train acc:0.91, test acc:0.7389
# epoch:183, train acc:0.9233333333333333, test acc:0.7526
# epoch:184, train acc:0.9133333333333333, test acc:0.7479
# epoch:185, train acc:0.9233333333333333, test acc:0.7449
# epoch:186, train acc:0.9133333333333333, test acc:0.7382
# epoch:187, train acc:0.91, test acc:0.7465
# epoch:188, train acc:0.92, test acc:0.747
# epoch:189, train acc:0.9133333333333333, test acc:0.7436
# epoch:190, train acc:0.9166666666666666, test acc:0.7465
# epoch:191, train acc:0.93, test acc:0.7478
# epoch:192, train acc:0.9033333333333333, test acc:0.7413
# epoch:193, train acc:0.9266666666666666, test acc:0.7478
# epoch:194, train acc:0.9133333333333333, test acc:0.7437
# epoch:195, train acc:0.9166666666666666, test acc:0.7436
# epoch:196, train acc:0.9133333333333333, test acc:0.745
# epoch:197, train acc:0.9, test acc:0.7359
# epoch:198, train acc:0.9133333333333333, test acc:0.7413
# epoch:199, train acc:0.9266666666666666, test acc:0.7415
# epoch:200, train acc:0.93, test acc:0.7529

# %%
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
